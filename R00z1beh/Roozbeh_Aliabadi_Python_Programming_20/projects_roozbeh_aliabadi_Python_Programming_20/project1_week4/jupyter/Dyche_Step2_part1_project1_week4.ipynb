# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('FBI_CrimeData_2016.json')

# Display the DataFrame
df.head()
# Out:
#   Region    State         City Population  Murder  Rape  Robbery  Assault  \
# 0  South  ALABAMA    Abbeville       2608       0     1        0       10
# 1  South  ALABAMA   Adamsville       4377       0     0       10        9
# 2  South  ALABAMA      Addison        738       0     0        0        1
# 3  South  ALABAMA    Alabaster      33040       1     2        2       92
# 4  South  ALABAMA  Albertville      21525       0     5       10       14
#
#    Burglary  Theft  Vehicle_Theft
# 0        12     34              5
# 1        33    201             16
# 2         1     11              2
# 3        58    411             19
# 4       190    462             69

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9579 entries, 0 to 9578
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         9579 non-null   object
#  1   State          9579 non-null   object
#  2   City           9579 non-null   object
#  3   Population     9579 non-null   object
#  4   Murder         9579 non-null   int64
#  5   Rape           9579 non-null   int64
#  6   Robbery        9579 non-null   int64
#  7   Assault        9579 non-null   int64
#  8   Burglary       9579 non-null   int64
#  9   Theft          9579 non-null   int64
#  10  Vehicle_Theft  9579 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 823.3+ KB

# %%
def frequency_table(variable):
    
    percentage_of_nan_systemic = ( len(variable) - len(variable.dropna()) ) / len(variable) * 100
#     percentage_of_nan = 123
    # Get unique elements and their counts
    VARIABLE = variable.dropna()
    unique_elements, counts = np.unique(VARIABLE, return_counts=True)

    # Calculate percentages
    percentages = (counts / len(variable)) * 100

    # Create a dictionary to store the value counts and percentages
    value_counts_and_percentages = zip( unique_elements , counts , percentages  )

    # Print the value counts and percentages
    for i, j, k in value_counts_and_percentages:
        print( f"{i}: Count: {j}, Percentage: {k:.2f}%"  )
    print("percentage_of_nan_systemic : ", percentage_of_nan_systemic,"%"  )
    return



categorical_variables = ["Region","State","City"]

for var in categorical_variables :
    frequency_table(df[var])
    print("#"*90)
# Out:
# Midwest: Count: 2829, Percentage: 29.53%
# Northeast: Count: 2403, Percentage: 25.09%
# South: Count: 3038, Percentage: 31.72%
# West: Count: 1309, Percentage: 13.67%
# percentage_of_nan_systemic :  0.0 %
# ##########################################################################################
# ALABAMA: Count: 201, Percentage: 2.10%
# ALASKA: Count: 27, Percentage: 0.28%
# ARIZONA: Count: 60, Percentage: 0.63%
# ARKANSAS: Count: 194, Percentage: 2.03%
# CALIFORNIA: Count: 461, Percentage: 4.81%
# COLORADO: Count: 129, Percentage: 1.35%
# CONNECTICUT: Count: 90, Percentage: 0.94%
# DELAWARE: Count: 36, Percentage: 0.38%
# DISTRICT OF COLUMBIA: Count: 1, Percentage: 0.01%
# FLORIDA: Count: 284, Percentage: 2.96%
# GEORGIA: Count: 286, Percentage: 2.99%
# HAWAII: Count: 1, Percentage: 0.01%
# IDAHO: Count: 63, Percentage: 0.66%
# ILLINOIS: Count: 532, Percentage: 5.55%
# INDIANA: Count: 98, Percentage: 1.02%
# IOWA: Count: 124, Percentage: 1.29%
# KANSAS: Count: 132, Percentage: 1.38%
# KENTUCKY: Count: 233, Percentage: 2.43%
# LOUISIANA: Count: 106, Percentage: 1.11%
# MAINE: Count: 112, Percentage: 1.17%
# MARYLAND: Count: 74, Percentage: 0.77%
# MASSACHUSETTS: Count: 276, Percentage: 2.88%
# MICHIGAN: Count: 416, Percentage: 4.34%
# MINNESOTA: Count: 261, Percentage: 2.72%
# MISSISSIPPI: Count: 37, Percentage: 0.39%
# MISSOURI: Count: 418, Percentage: 4.36%
# MONTANA: Count: 44, Percentage: 0.46%
# NEBRASKA: Count: 58, Percentage: 0.61%
# NEVADA: Count: 14, Percentage: 0.15%
# NEW HAMPSHIRE: Count: 156, Percentage: 1.63%
# NEW JERSEY: Count: 486, Percentage: 5.07%
# NEW MEXICO: Count: 60, Percentage: 0.63%
# NEW YORK: Count: 387, Percentage: 4.04%
# NORTH CAROLINA: Count: 182, Percentage: 1.90%
# NORTH DAKOTA: Count: 48, Percentage: 0.50%
# OHIO: Count: 368, Percentage: 3.84%
# OKLAHOMA: Count: 223, Percentage: 2.33%
# OREGON: Count: 97, Percentage: 1.01%
# PENNSYLVANIA: Count: 827, Percentage: 8.63%
# RHODE ISLAND: Count: 37, Percentage: 0.39%
# SOUTH CAROLINA: Count: 160, Percentage: 1.67%
# SOUTH DAKOTA: Count: 53, Percentage: 0.55%
# TENNESSEE: Count: 249, Percentage: 2.60%
# TEXAS: Count: 625, Percentage: 6.52%
# UTAH: Count: 80, Percentage: 0.84%
# VERMONT: Count: 32, Percentage: 0.33%
# VIRGINIA: Count: 147, Percentage: 1.53%
# WASHINGTON: Count: 182, Percentage: 1.90%
# WEST VIRGINIA: Count: 58, Percentage: 0.61%
# WISCONSIN: Count: 321, Percentage: 3.35%
# WYOMING: Count: 33, Percentage: 0.34%
# percentage_of_nan_systemic :  0.0 %
# ##########################################################################################
# Abbeville: Count: 4, Percentage: 0.04%
# Aberdeen: Count: 5, Percentage: 0.05%
# Aberdeen Township: Count: 1, Percentage: 0.01%
# Abernathy: Count: 1, Percentage: 0.01%
# Abilene: Count: 2, Percentage: 0.02%
# Abingdon: Count: 1, Percentage: 0.01%
# Abington: Count: 1, Percentage: 0.01%
# Abington Township, Montgomery County: Count: 1, Percentage: 0.01%
# Absecon: Count: 1, Percentage: 0.01%
# Ackerman: Count: 1, Percentage: 0.01%
# Acton: Count: 1, Percentage: 0.01%
# Acushnet: Count: 1, Percentage: 0.01%
# Acworth: Count: 1, Percentage: 0.01%
# Ada: Count: 2, Percentage: 0.02%
# Adairsville: Count: 1, Percentage: 0.01%
# Adairville: Count: 1, Percentage: 0.01%
# Adams: Count: 2, Percentage: 0.02%
# Adams Township, Butler County: Count: 1, Percentage: 0.01%
# Adams Village: Count: 1, Percentage: 0.01%
# Adamstown: Count: 1, Percentage: 0.01%
# Adamsville: Count: 2, Percentage: 0.02%
# Addis: Count: 1, Percentage: 0.01%
# Addison: Count: 3, Percentage: 0.03%
# Addison Town and Village: Count: 1, Percentage: 0.01%
# Addison Township: Count: 1, Percentage: 0.01%
# Adel: Count: 2, Percentage: 0.02%
# Adelanto: Count: 1, Percentage: 0.01%
# Adrian: Count: 1, Percentage: 0.01%
# Advance: Count: 1, Percentage: 0.01%
# Afton: Count: 1, Percentage: 0.01%
# Agawam: Count: 1, Percentage: 0.01%
# Agoura Hills: Count: 1, Percentage: 0.01%
# Ahoskie: Count: 1, Percentage: 0.01%
# Aiken: Count: 1, Percentage: 0.01%
# Aitkin: Count: 1, Percentage: 0.01%
# Akeley: Count: 1, Percentage: 0.01%
# Akron: Count: 3, Percentage: 0.03%
# Akron Village: Count: 1, Percentage: 0.01%
# Alabaster: Count: 1, Percentage: 0.01%
# Alachua: Count: 1, Percentage: 0.01%
# Alameda: Count: 1, Percentage: 0.01%
# Alamo: Count: 3, Percentage: 0.03%
# Alamo Heights: Count: 1, Percentage: 0.01%
# Alamogordo: Count: 1, Percentage: 0.01%
# Alapaha: Count: 1, Percentage: 0.01%
# Albany: Count: 9, Percentage: 0.09%
# Albemarle: Count: 1, Percentage: 0.01%
# Albert Lea: Count: 1, Percentage: 0.01%
# Albertville: Count: 1, Percentage: 0.01%
# Albia: Count: 1, Percentage: 0.01%
# Albion: Count: 2, Percentage: 0.02%
# Albion Village: Count: 1, Percentage: 0.01%
# Albuquerque: Count: 1, Percentage: 0.01%
# Alcester: Count: 1, Percentage: 0.01%
# Alcoa: Count: 1, Percentage: 0.01%
# Aldan: Count: 1, Percentage: 0.01%
# Alderson: Count: 1, Percentage: 0.01%
# Aledo: Count: 1, Percentage: 0.01%
# Aleppo Township: Count: 1, Percentage: 0.01%
# Alexander: Count: 1, Percentage: 0.01%
# Alexander City: Count: 1, Percentage: 0.01%
# Alexandria: Count: 7, Percentage: 0.07%
# Alexandria Bay Village: Count: 1, Percentage: 0.01%
# Alexis: Count: 1, Percentage: 0.01%
# Alfred Village: Count: 1, Percentage: 0.01%
# Algoma: Count: 1, Percentage: 0.01%
# Algona: Count: 2, Percentage: 0.02%
# Algonquin: Count: 1, Percentage: 0.01%
# Algood: Count: 1, Percentage: 0.01%
# Alhambra: Count: 1, Percentage: 0.01%
# Alice: Count: 1, Percentage: 0.01%
# Aliceville: Count: 1, Percentage: 0.01%
# Aliso Viejo: Count: 1, Percentage: 0.01%
# Allegan: Count: 1, Percentage: 0.01%
# Allegany Village: Count: 1, Percentage: 0.01%
# Allegheny Township, Blair County: Count: 1, Percentage: 0.01%
# Allegheny Township, Westmoreland County: Count: 1, Percentage: 0.01%
# Allen: Count: 3, Percentage: 0.03%
# Allen Park: Count: 1, Percentage: 0.01%
# Allendale: Count: 2, Percentage: 0.02%
# Allenhurst: Count: 1, Percentage: 0.01%
# Allentown: Count: 2, Percentage: 0.02%
# Alliance: Count: 1, Percentage: 0.01%
# Alliance7: Count: 1, Percentage: 0.01%
# Alma: Count: 5, Percentage: 0.05%
# Almont: Count: 1, Percentage: 0.01%
# Alpena: Count: 1, Percentage: 0.01%
# Alpha: Count: 1, Percentage: 0.01%
# Alpharetta: Count: 1, Percentage: 0.01%
# Alpine: Count: 2, Percentage: 0.02%
# Alsip: Count: 1, Percentage: 0.01%
# Alstead: Count: 1, Percentage: 0.01%
# Altamont: Count: 1, Percentage: 0.01%
# Altamont Village: Count: 1, Percentage: 0.01%
# Altamonte Springs: Count: 1, Percentage: 0.01%
# Altavista: Count: 1, Percentage: 0.01%
# Alto: Count: 1, Percentage: 0.01%
# Alton: Count: 3, Percentage: 0.03%
# Altoona: Count: 3, Percentage: 0.03%
# Alturas: Count: 1, Percentage: 0.01%
# Altus: Count: 2, Percentage: 0.02%
# Alva: Count: 1, Percentage: 0.01%
# Alvarado: Count: 1, Percentage: 0.01%
# Alvin: Count: 1, Percentage: 0.01%
# Amarillo: Count: 1, Percentage: 0.01%
# Amberley Village: Count: 1, Percentage: 0.01%
# Ambler: Count: 1, Percentage: 0.01%
# Amboy: Count: 1, Percentage: 0.01%
# Ambridge: Count: 1, Percentage: 0.01%
# Amelia: Count: 1, Percentage: 0.01%
# American Canyon : Count: 1, Percentage: 0.01%
# American Falls: Count: 1, Percentage: 0.01%
# American Fork/Cedar Hills: Count: 1, Percentage: 0.01%
# American Township: Count: 1, Percentage: 0.01%
# Americus: Count: 1, Percentage: 0.01%
# Amery: Count: 1, Percentage: 0.01%
# Ames: Count: 1, Percentage: 0.01%
# Amherst: Count: 4, Percentage: 0.04%
# Amherst Town: Count: 1, Percentage: 0.01%
# Amity: Count: 2, Percentage: 0.02%
# Amity Town and Belmont Village: Count: 1, Percentage: 0.01%
# Amity Township: Count: 1, Percentage: 0.01%
# Amityville Village: Count: 1, Percentage: 0.01%
# Amory: Count: 1, Percentage: 0.01%
# Amsterdam: Count: 1, Percentage: 0.01%
# Anacortes: Count: 1, Percentage: 0.01%
# Anadarko: Count: 1, Percentage: 0.01%
# Anaheim: Count: 1, Percentage: 0.01%
# Anamosa: Count: 1, Percentage: 0.01%
# Anchorage: Count: 2, Percentage: 0.02%
# Andale: Count: 1, Percentage: 0.01%
# Andalusia: Count: 1, Percentage: 0.01%
# Anderson: Count: 3, Percentage: 0.03%
# Andover: Count: 2, Percentage: 0.02%
# Andover Township: Count: 1, Percentage: 0.01%
# Andover Village: Count: 1, Percentage: 0.01%
# Andrews: Count: 2, Percentage: 0.02%
# Angel Fire: Count: 1, Percentage: 0.01%
# Angelica Village: Count: 1, Percentage: 0.01%
# Angels Camp: Count: 1, Percentage: 0.01%
# Angier: Count: 1, Percentage: 0.01%
# Angleton: Count: 1, Percentage: 0.01%
# Ankeny: Count: 1, Percentage: 0.01%
# Ann Arbor: Count: 1, Percentage: 0.01%
# Anna: Count: 2, Percentage: 0.02%
# Annandale: Count: 1, Percentage: 0.01%
# Annapolis: Count: 2, Percentage: 0.02%
# Annawan: Count: 1, Percentage: 0.01%
# Anniston: Count: 1, Percentage: 0.01%
# Annville Township: Count: 1, Percentage: 0.01%
# Anoka: Count: 1, Percentage: 0.01%
# Anson: Count: 1, Percentage: 0.01%
# Ansonia: Count: 1, Percentage: 0.01%
# Anthony: Count: 2, Percentage: 0.02%
# Antigo: Count: 1, Percentage: 0.01%
# Antioch: Count: 2, Percentage: 0.02%
# Antlers: Count: 1, Percentage: 0.01%
# Antrim: Count: 1, Percentage: 0.01%
# Apache: Count: 1, Percentage: 0.01%
# Apache Junction: Count: 1, Percentage: 0.01%
# Apalachicola: Count: 1, Percentage: 0.01%
# Apex: Count: 1, Percentage: 0.01%
# Apollo: Count: 1, Percentage: 0.01%
# Apopka: Count: 1, Percentage: 0.01%
# Appalachia: Count: 1, Percentage: 0.01%
# Apple Valley: Count: 2, Percentage: 0.02%
# Appleton: Count: 2, Percentage: 0.02%
# Arab: Count: 1, Percentage: 0.01%
# Aragon: Count: 1, Percentage: 0.01%
# Aransas Pass: Count: 1, Percentage: 0.01%
# Arcade: Count: 1, Percentage: 0.01%
# Arcade Village: Count: 1, Percentage: 0.01%
# Arcadia: Count: 4, Percentage: 0.04%
# Arcata: Count: 1, Percentage: 0.01%
# Archbald: Count: 1, Percentage: 0.01%
# Archbold: Count: 1, Percentage: 0.01%
# Archie: Count: 1, Percentage: 0.01%
# Arcola: Count: 1, Percentage: 0.01%
# Ardmore: Count: 3, Percentage: 0.03%
# Ardsley Village: Count: 1, Percentage: 0.01%
# Argentine Township: Count: 1, Percentage: 0.01%
# Argo: Count: 1, Percentage: 0.01%
# Argyle: Count: 1, Percentage: 0.01%
# Arkadelphia: Count: 1, Percentage: 0.01%
# Arkansas City: Count: 1, Percentage: 0.01%
# Arkoma: Count: 1, Percentage: 0.01%
# Arlington: Count: 5, Percentage: 0.05%
# Arlington Heights: Count: 1, Percentage: 0.01%
# Arma: Count: 1, Percentage: 0.01%
# Armada: Count: 1, Percentage: 0.01%
# Armagh Township: Count: 1, Percentage: 0.01%
# Arnegard: Count: 1, Percentage: 0.01%
# Arnold: Count: 1, Percentage: 0.01%
# Arp: Count: 1, Percentage: 0.01%
# Arroyo Grande: Count: 1, Percentage: 0.01%
# Artesia: Count: 2, Percentage: 0.02%
# Arthur: Count: 1, Percentage: 0.01%
# Arvin: Count: 1, Percentage: 0.01%
# Asbury Park: Count: 1, Percentage: 0.01%
# Ash Flat: Count: 1, Percentage: 0.01%
# Ash Grove: Count: 1, Percentage: 0.01%
# Asharoken Village: Count: 1, Percentage: 0.01%
# Ashburn: Count: 1, Percentage: 0.01%
# Ashburnham: Count: 1, Percentage: 0.01%
# Ashby: Count: 1, Percentage: 0.01%
# Ashdown: Count: 1, Percentage: 0.01%
# Asheboro: Count: 1, Percentage: 0.01%
# Asheville: Count: 1, Percentage: 0.01%
# Ashford: Count: 1, Percentage: 0.01%
# Ashland: Count: 11, Percentage: 0.11%
# Ashland City: Count: 1, Percentage: 0.01%
# Ashland10: Count: 1, Percentage: 0.01%
# Ashley: Count: 1, Percentage: 0.01%
# Ashville: Count: 2, Percentage: 0.02%
# Ashwaubenon7: Count: 1, Percentage: 0.01%
# Asotin: Count: 1, Percentage: 0.01%
# Aspen: Count: 1, Percentage: 0.01%
# Aspinwall: Count: 1, Percentage: 0.01%
# Assaria: Count: 1, Percentage: 0.01%
# Assumption: Count: 1, Percentage: 0.01%
# Aston Township: Count: 1, Percentage: 0.01%
# Astoria: Count: 1, Percentage: 0.01%
# Atascadero: Count: 1, Percentage: 0.01%
# Atchison: Count: 1, Percentage: 0.01%
# Athens: Count: 7, Percentage: 0.07%
# Athens Township: Count: 1, Percentage: 0.01%
# Athens-Clarke County: Count: 1, Percentage: 0.01%
# Atherton: Count: 1, Percentage: 0.01%
# Athol: Count: 1, Percentage: 0.01%
# Atkins: Count: 1, Percentage: 0.01%
# Atkinson: Count: 1, Percentage: 0.01%
# Atlanta: Count: 2, Percentage: 0.02%
# Atlantic Beach: Count: 3, Percentage: 0.03%
# Atlantic Highlands: Count: 1, Percentage: 0.01%
# Atlantis: Count: 1, Percentage: 0.01%
# Atmore: Count: 1, Percentage: 0.01%
# Atoka: Count: 2, Percentage: 0.02%
# Attalla: Count: 1, Percentage: 0.01%
# Attapulgus: Count: 1, Percentage: 0.01%
# Attica Village: Count: 1, Percentage: 0.01%
# Attleboro: Count: 1, Percentage: 0.01%
# Atwater: Count: 2, Percentage: 0.02%
# Atwood: Count: 1, Percentage: 0.01%
# Au Gres: Count: 1, Percentage: 0.01%
# Aubrey: Count: 1, Percentage: 0.01%
# Auburn: Count: 12, Percentage: 0.13%
# Auburn Hills: Count: 1, Percentage: 0.01%
# Auburndale: Count: 1, Percentage: 0.01%
# Audubon: Count: 2, Percentage: 0.02%
# Audubon Park: Count: 2, Percentage: 0.02%
# Augusta: Count: 4, Percentage: 0.04%
# Ault: Count: 1, Percentage: 0.01%
# Aumsville: Count: 1, Percentage: 0.01%
# Aurora: Count: 6, Percentage: 0.06%
# Austell: Count: 1, Percentage: 0.01%
# Austin: Count: 2, Percentage: 0.02%
# Austin4: Count: 1, Percentage: 0.01%
# Austintown: Count: 1, Percentage: 0.01%
# Auxvasse: Count: 1, Percentage: 0.01%
# Ava: Count: 1, Percentage: 0.01%
# Avalon: Count: 3, Percentage: 0.03%
# Avenal: Count: 1, Percentage: 0.01%
# Aventura: Count: 1, Percentage: 0.01%
# Avis: Count: 1, Percentage: 0.01%
# Aviston: Count: 1, Percentage: 0.01%
# Avoca: Count: 2, Percentage: 0.02%
# Avon: Count: 6, Percentage: 0.06%
# Avon Village: Count: 1, Percentage: 0.01%
# Avon-by-the-Sea: Count: 1, Percentage: 0.01%
# Avondale: Count: 1, Percentage: 0.01%
# Avondale Estates: Count: 1, Percentage: 0.01%
# Avonmore Boro: Count: 1, Percentage: 0.01%
# Ayden: Count: 1, Percentage: 0.01%
# Ayer: Count: 1, Percentage: 0.01%
# Aynor: Count: 1, Percentage: 0.01%
# Azle: Count: 1, Percentage: 0.01%
# Aztec: Count: 1, Percentage: 0.01%
# Azusa: Count: 1, Percentage: 0.01%
# Babbitt: Count: 1, Percentage: 0.01%
# Bad Axe: Count: 1, Percentage: 0.01%
# Baden: Count: 1, Percentage: 0.01%
# Bailey: Count: 1, Percentage: 0.01%
# Baileyton: Count: 1, Percentage: 0.01%
# Baileyville10: Count: 1, Percentage: 0.01%
# Bainbridge: Count: 1, Percentage: 0.01%
# Bainbridge Island: Count: 1, Percentage: 0.01%
# Bainbridge Village: Count: 1, Percentage: 0.01%
# Baird: Count: 1, Percentage: 0.01%
# Baker: Count: 1, Percentage: 0.01%
# Bakersfield: Count: 1, Percentage: 0.01%
# Bal Harbour Village: Count: 1, Percentage: 0.01%
# Balch Springs: Count: 1, Percentage: 0.01%
# Balcones Heights: Count: 1, Percentage: 0.01%
# Bald Knob: Count: 1, Percentage: 0.01%
# Baldwin: Count: 1, Percentage: 0.01%
# Baldwin Borough: Count: 1, Percentage: 0.01%
# Baldwin Park: Count: 1, Percentage: 0.01%
# Baldwinsville Village: Count: 1, Percentage: 0.01%
# Ball: Count: 1, Percentage: 0.01%
# Ball Ground: Count: 1, Percentage: 0.01%
# Ballinger: Count: 1, Percentage: 0.01%
# Ballston Spa Village: Count: 1, Percentage: 0.01%
# Ballwin: Count: 1, Percentage: 0.01%
# Bally: Count: 1, Percentage: 0.01%
# Balsam Lake: Count: 1, Percentage: 0.01%
# Baltimore: Count: 2, Percentage: 0.02%
# Baltimore City Sheriff: Count: 1, Percentage: 0.01%
# Bamberg: Count: 1, Percentage: 0.01%
# Bancroft: Count: 1, Percentage: 0.01%
# Baneberry: Count: 1, Percentage: 0.01%
# Bangor: Count: 3, Percentage: 0.03%
# Bangor10: Count: 1, Percentage: 0.01%
# Bangs: Count: 1, Percentage: 0.01%
# Banks: Count: 1, Percentage: 0.01%
# Banner Elk: Count: 1, Percentage: 0.01%
# Banning: Count: 1, Percentage: 0.01%
# Bannockburn: Count: 1, Percentage: 0.01%
# Bar Harbor7: Count: 1, Percentage: 0.01%
# Baraboo: Count: 1, Percentage: 0.01%
# Barberton: Count: 1, Percentage: 0.01%
# Barboursville: Count: 1, Percentage: 0.01%
# Barbourville: Count: 1, Percentage: 0.01%
# Bardstown: Count: 1, Percentage: 0.01%
# Bardwell: Count: 1, Percentage: 0.01%
# Bargersville: Count: 1, Percentage: 0.01%
# Barling: Count: 1, Percentage: 0.01%
# Barnegat Light: Count: 1, Percentage: 0.01%
# Barnegat Township: Count: 1, Percentage: 0.01%
# Barnesville: Count: 3, Percentage: 0.03%
# Barneveld: Count: 1, Percentage: 0.01%
# Barnsdall: Count: 1, Percentage: 0.01%
# Barnstable: Count: 1, Percentage: 0.01%
# Barnstead: Count: 1, Percentage: 0.01%
# Barnwell: Count: 1, Percentage: 0.01%
# Baroda-Lake Township: Count: 1, Percentage: 0.01%
# Barre Town: Count: 1, Percentage: 0.01%
# Barrington: Count: 4, Percentage: 0.04%
# Barrington Hills: Count: 1, Percentage: 0.01%
# Barron: Count: 1, Percentage: 0.01%
# Barry: Count: 1, Percentage: 0.01%
# Barry Township: Count: 1, Percentage: 0.01%
# Barryton: Count: 1, Percentage: 0.01%
# Barstow: Count: 1, Percentage: 0.01%
# Bartlesville: Count: 1, Percentage: 0.01%
# Bartlett: Count: 2, Percentage: 0.02%
# Bartonville: Count: 2, Percentage: 0.02%
# Bartow: Count: 1, Percentage: 0.01%
# Basalt: Count: 1, Percentage: 0.01%
# Basehor: Count: 1, Percentage: 0.01%
# Bastrop: Count: 2, Percentage: 0.02%
# Batavia: Count: 3, Percentage: 0.03%
# Bates City: Count: 1, Percentage: 0.01%
# Batesburg-Leesville: Count: 1, Percentage: 0.01%
# Batesville: Count: 3, Percentage: 0.03%
# Bath Township: Count: 1, Percentage: 0.01%
# Bath Township, Summit County: Count: 1, Percentage: 0.01%
# Bath Village: Count: 1, Percentage: 0.01%
# Bath10: Count: 1, Percentage: 0.01%
# Baton Rouge: Count: 1, Percentage: 0.01%
# Battle Creek: Count: 1, Percentage: 0.01%
# Battle Ground: Count: 1, Percentage: 0.01%
# Battlefield: Count: 1, Percentage: 0.01%
# Baudette: Count: 1, Percentage: 0.01%
# Baxley: Count: 1, Percentage: 0.01%
# Baxter: Count: 2, Percentage: 0.02%
# Baxter Springs: Count: 1, Percentage: 0.01%
# Bay: Count: 1, Percentage: 0.01%
# Bay City: Count: 2, Percentage: 0.02%
# Bay Harbor Islands: Count: 1, Percentage: 0.01%
# Bay Head: Count: 1, Percentage: 0.01%
# Bayard: Count: 1, Percentage: 0.01%
# Bayfield: Count: 2, Percentage: 0.02%
# Bayonne: Count: 1, Percentage: 0.01%
# Bayou La Batre: Count: 1, Percentage: 0.01%
# Bayou Vista: Count: 1, Percentage: 0.01%
# Bayport: Count: 1, Percentage: 0.01%
# Bayside: Count: 1, Percentage: 0.01%
# Baytown: Count: 1, Percentage: 0.01%
# Bazetta Township: Count: 1, Percentage: 0.01%
# Beach Haven: Count: 1, Percentage: 0.01%
# Beachwood: Count: 1, Percentage: 0.01%
# Beacon: Count: 1, Percentage: 0.01%
# Bean Station: Count: 1, Percentage: 0.01%
# Bear Creek: Count: 1, Percentage: 0.01%
# Bear Valley: Count: 1, Percentage: 0.01%
# Bearden: Count: 1, Percentage: 0.01%
# Beardstown5: Count: 1, Percentage: 0.01%
# Beatrice: Count: 1, Percentage: 0.01%
# Beattyville: Count: 1, Percentage: 0.01%
# Beaufort: Count: 2, Percentage: 0.02%
# Beaumont: Count: 2, Percentage: 0.02%
# Beaver: Count: 2, Percentage: 0.02%
# Beaver Dam: Count: 2, Percentage: 0.02%
# Beaver Dam Township: Count: 1, Percentage: 0.01%
# Beaver Falls: Count: 1, Percentage: 0.01%
# Beaver Township: Count: 1, Percentage: 0.01%
# Beavercreek: Count: 1, Percentage: 0.01%
# Beaverton: Count: 2, Percentage: 0.02%
# Becker: Count: 1, Percentage: 0.01%
# Becket: Count: 1, Percentage: 0.01%
# Beckley: Count: 1, Percentage: 0.01%
# Bedford: Count: 7, Percentage: 0.07%
# Bedford Heights: Count: 1, Percentage: 0.01%
# Bedford Town: Count: 1, Percentage: 0.01%
# Bedminster Township: Count: 2, Percentage: 0.02%
# Bee Cave: Count: 1, Percentage: 0.01%
# Beebe: Count: 1, Percentage: 0.01%
# Beech Bottom: Count: 1, Percentage: 0.01%
# Beech Grove: Count: 1, Percentage: 0.01%
# Beech Mountain: Count: 1, Percentage: 0.01%
# Beecher: Count: 1, Percentage: 0.01%
# Beeville: Count: 1, Percentage: 0.01%
# Beggs: Count: 1, Percentage: 0.01%
# Bel Air: Count: 1, Percentage: 0.01%
# Bel Aire: Count: 1, Percentage: 0.01%
# Bel-Nor: Count: 1, Percentage: 0.01%
# Bel-Ridge: Count: 1, Percentage: 0.01%
# Belchertown: Count: 1, Percentage: 0.01%
# Belding: Count: 1, Percentage: 0.01%
# Belen: Count: 1, Percentage: 0.01%
# Belfast10: Count: 1, Percentage: 0.01%
# Belfield: Count: 1, Percentage: 0.01%
# Belgium: Count: 1, Percentage: 0.01%
# Belgrade: Count: 1, Percentage: 0.01%
# Belgrade/Brooten: Count: 1, Percentage: 0.01%
# Belhaven: Count: 1, Percentage: 0.01%
# Belington: Count: 1, Percentage: 0.01%
# Bell: Count: 1, Percentage: 0.01%
# Bell Acres: Count: 1, Percentage: 0.01%
# Bell Gardens: Count: 1, Percentage: 0.01%
# Bella Villa: Count: 1, Percentage: 0.01%
# Bella Vista: Count: 1, Percentage: 0.01%
# Bellaire: Count: 3, Percentage: 0.03%
# Bellbrook: Count: 1, Percentage: 0.01%
# Belle: Count: 1, Percentage: 0.01%
# Belle Fourche: Count: 1, Percentage: 0.01%
# Belle Glade: Count: 1, Percentage: 0.01%
# Belle Isle: Count: 1, Percentage: 0.01%
# Belle Meade: Count: 1, Percentage: 0.01%
# Belle Plaine: Count: 1, Percentage: 0.01%
# Belleair: Count: 1, Percentage: 0.01%
# Belleair Beach: Count: 1, Percentage: 0.01%
# Belleair Bluffs: Count: 1, Percentage: 0.01%
# Bellefontaine: Count: 1, Percentage: 0.01%
# Bellefontaine Neighbors: Count: 1, Percentage: 0.01%
# Bellefonte: Count: 1, Percentage: 0.01%
# Belleview: Count: 1, Percentage: 0.01%
# Belleville: Count: 4, Percentage: 0.04%
# Bellevue: Count: 6, Percentage: 0.06%
# Bellflower: Count: 2, Percentage: 0.02%
# Bellingham: Count: 2, Percentage: 0.02%
# Bellmawr: Count: 1, Percentage: 0.01%
# Bellmead: Count: 1, Percentage: 0.01%
# Bellows Falls: Count: 1, Percentage: 0.01%
# Bells: Count: 1, Percentage: 0.01%
# Bellville: Count: 2, Percentage: 0.02%
# Bellwood: Count: 2, Percentage: 0.02%
# Belmar: Count: 1, Percentage: 0.01%
# Belmond: Count: 1, Percentage: 0.01%
# Belmont: Count: 4, Percentage: 0.04%
# Beloit: Count: 2, Percentage: 0.02%
# Beloit Town: Count: 1, Percentage: 0.01%
# Belpre: Count: 1, Percentage: 0.01%
# Belton: Count: 3, Percentage: 0.03%
# Belvedere: Count: 1, Percentage: 0.01%
# Belvidere: Count: 2, Percentage: 0.02%
# Bemidji: Count: 1, Percentage: 0.01%
# Ben Avon: Count: 1, Percentage: 0.01%
# Ben Avon Heights: Count: 1, Percentage: 0.01%
# Benbrook: Count: 1, Percentage: 0.01%
# Bend: Count: 1, Percentage: 0.01%
# Benham: Count: 1, Percentage: 0.01%
# Benicia: Count: 1, Percentage: 0.01%
# Bennettsville: Count: 1, Percentage: 0.01%
# Bennington: Count: 3, Percentage: 0.03%
# Bensalem Township: Count: 1, Percentage: 0.01%
# Bensenville: Count: 1, Percentage: 0.01%
# Benson: Count: 2, Percentage: 0.02%
# Benton: Count: 4, Percentage: 0.04%
# Benton Harbor: Count: 1, Percentage: 0.01%
# Benton Township: Count: 1, Percentage: 0.01%
# Bentonville: Count: 1, Percentage: 0.01%
# Benwood: Count: 1, Percentage: 0.01%
# Berea: Count: 2, Percentage: 0.02%
# Beresford: Count: 1, Percentage: 0.01%
# Bergenfield: Count: 1, Percentage: 0.01%
# Berkeley: Count: 2, Percentage: 0.02%
# Berkeley Heights Township: Count: 1, Percentage: 0.01%
# Berkeley Township: Count: 1, Percentage: 0.01%
# Berkley: Count: 2, Percentage: 0.02%
# Berlin: Count: 8, Percentage: 0.08%
# Berlin Township: Count: 1, Percentage: 0.01%
# Bern Township: Count: 1, Percentage: 0.01%
# Bernalillo: Count: 1, Percentage: 0.01%
# Bernards Township: Count: 1, Percentage: 0.01%
# Bernardston: Count: 1, Percentage: 0.01%
# Bernardsville: Count: 1, Percentage: 0.01%
# Berne: Count: 1, Percentage: 0.01%
# Bernie: Count: 1, Percentage: 0.01%
# Berrien Springs-Oronoko Township: Count: 1, Percentage: 0.01%
# Berry Hill: Count: 1, Percentage: 0.01%
# Berryville: Count: 2, Percentage: 0.02%
# Berthold: Count: 1, Percentage: 0.01%
# Bertrand: Count: 1, Percentage: 0.01%
# Berwick: Count: 2, Percentage: 0.02%
# Berwick10: Count: 1, Percentage: 0.01%
# Berwyn: Count: 1, Percentage: 0.01%
# Berwyn Heights: Count: 1, Percentage: 0.01%
# Bessemer: Count: 1, Percentage: 0.01%
# Bessemer City: Count: 1, Percentage: 0.01%
# Bethalto: Count: 1, Percentage: 0.01%
# Bethany: Count: 2, Percentage: 0.02%
# Bethany Beach: Count: 1, Percentage: 0.01%
# Bethel: Count: 3, Percentage: 0.03%
# Bethel Heights: Count: 1, Percentage: 0.01%
# Bethel Park: Count: 1, Percentage: 0.01%
# Bethel Township, Berks County: Count: 1, Percentage: 0.01%
# Bethlehem: Count: 2, Percentage: 0.02%
# Bethlehem Town: Count: 1, Percentage: 0.01%
# Bethlehem Township: Count: 1, Percentage: 0.01%
# Bethlehem5: Count: 1, Percentage: 0.01%
# Bettendorf4: Count: 1, Percentage: 0.01%
# Beulah: Count: 1, Percentage: 0.01%
# Beverly: Count: 2, Percentage: 0.02%
# Beverly Hills: Count: 4, Percentage: 0.04%
# Bexley: Count: 1, Percentage: 0.01%
# Biddeford7: Count: 1, Percentage: 0.01%
# Big Bear: Count: 1, Percentage: 0.01%
# Big Bend: Count: 1, Percentage: 0.01%
# Big Cabin: Count: 1, Percentage: 0.01%
# Big Lake: Count: 1, Percentage: 0.01%
# Big Rapids: Count: 1, Percentage: 0.01%
# Big Sandy: Count: 2, Percentage: 0.02%
# Big Spring: Count: 1, Percentage: 0.01%
# Big Stone Gap: Count: 1, Percentage: 0.01%
# Big Water: Count: 1, Percentage: 0.01%
# Biggs: Count: 1, Percentage: 0.01%
# Biglerville: Count: 1, Percentage: 0.01%
# Billerica: Count: 1, Percentage: 0.01%
# Billings: Count: 2, Percentage: 0.02%
# Biloxi: Count: 1, Percentage: 0.01%
# Biltmore Forest: Count: 1, Percentage: 0.01%
# Bingen: Count: 1, Percentage: 0.01%
# Binghamton: Count: 1, Percentage: 0.01%
# Birch Run: Count: 1, Percentage: 0.01%
# Birch Tree: Count: 1, Percentage: 0.01%
# Birdsboro: Count: 1, Percentage: 0.01%
# Birmingham: Count: 1, Percentage: 0.01%
# Birmingham Township: Count: 1, Percentage: 0.01%
# Biscayne Park: Count: 1, Percentage: 0.01%
# Biscoe: Count: 1, Percentage: 0.01%
# Bishop: Count: 2, Percentage: 0.02%
# Bishopville: Count: 1, Percentage: 0.01%
# Bismarck: Count: 2, Percentage: 0.02%
# Bixby: Count: 1, Percentage: 0.01%
# Black Butte: Count: 1, Percentage: 0.01%
# Black Diamond: Count: 1, Percentage: 0.01%
# Black Hawk: Count: 1, Percentage: 0.01%
# Black Mountain: Count: 1, Percentage: 0.01%
# Black River: Count: 1, Percentage: 0.01%
# Black River Falls: Count: 1, Percentage: 0.01%
# Black Rock: Count: 1, Percentage: 0.01%
# Blackburn: Count: 1, Percentage: 0.01%
# Blackduck: Count: 1, Percentage: 0.01%
# Blackfoot: Count: 1, Percentage: 0.01%
# Blackman Township: Count: 1, Percentage: 0.01%
# Blacksburg: Count: 2, Percentage: 0.02%
# Blackshear: Count: 1, Percentage: 0.01%
# Blackstone: Count: 2, Percentage: 0.02%
# Blackville: Count: 1, Percentage: 0.01%
# Blackwell: Count: 1, Percentage: 0.01%
# Bladensburg: Count: 1, Percentage: 0.01%
# Blades: Count: 1, Percentage: 0.01%
# Blaine: Count: 3, Percentage: 0.03%
# Blair: Count: 2, Percentage: 0.02%
# Blair Township: Count: 1, Percentage: 0.01%
# Blairstown Township: Count: 1, Percentage: 0.01%
# Blairsville: Count: 2, Percentage: 0.02%
# Blakely: Count: 2, Percentage: 0.02%
# Blanchard: Count: 2, Percentage: 0.02%
# Blanchardville: Count: 1, Percentage: 0.01%
# Blanchester: Count: 1, Percentage: 0.01%
# Blanco: Count: 1, Percentage: 0.01%
# Blanding: Count: 1, Percentage: 0.01%
# Blandinsville: Count: 1, Percentage: 0.01%
# Blawnox: Count: 1, Percentage: 0.01%
# Blissfield: Count: 1, Percentage: 0.01%
# Bloomer: Count: 1, Percentage: 0.01%
# Bloomfield: Count: 7, Percentage: 0.07%
# Bloomfield Hills: Count: 1, Percentage: 0.01%
# Bloomfield Township: Count: 1, Percentage: 0.01%
# Blooming Grove Town: Count: 1, Percentage: 0.01%
# Blooming Prairie: Count: 1, Percentage: 0.01%
# Bloomingdale: Count: 2, Percentage: 0.02%
# Bloomington: Count: 3, Percentage: 0.03%
# Blossburg: Count: 1, Percentage: 0.01%
# Blountstown: Count: 1, Percentage: 0.01%
# Blountsville: Count: 1, Percentage: 0.01%
# Blowing Rock: Count: 1, Percentage: 0.01%
# Blue Ash: Count: 1, Percentage: 0.01%
# Blue Earth: Count: 1, Percentage: 0.01%
# Blue Grass: Count: 1, Percentage: 0.01%
# Blue Island: Count: 1, Percentage: 0.01%
# Blue Mounds: Count: 1, Percentage: 0.01%
# Blue Ridge: Count: 1, Percentage: 0.01%
# Blue Springs: Count: 1, Percentage: 0.01%
# Bluefield: Count: 2, Percentage: 0.02%
# Bluff City: Count: 1, Percentage: 0.01%
# Bluffdale: Count: 1, Percentage: 0.01%
# Bluffs: Count: 1, Percentage: 0.01%
# Bluffton: Count: 3, Percentage: 0.03%
# Blythe: Count: 2, Percentage: 0.02%
# Blytheville: Count: 1, Percentage: 0.01%
# Boardman: Count: 1, Percentage: 0.01%
# Boaz: Count: 1, Percentage: 0.01%
# Boca Raton: Count: 1, Percentage: 0.01%
# Boerne7: Count: 1, Percentage: 0.01%
# Bogalusa: Count: 1, Percentage: 0.01%
# Bogata: Count: 1, Percentage: 0.01%
# Bogota: Count: 1, Percentage: 0.01%
# Boiling Spring Lakes: Count: 1, Percentage: 0.01%
# Boise: Count: 1, Percentage: 0.01%
# Boise City: Count: 1, Percentage: 0.01%
# Bolingbrook: Count: 1, Percentage: 0.01%
# Bolivar: Count: 2, Percentage: 0.02%
# Bolton: Count: 1, Percentage: 0.01%
# Bolton Town: Count: 1, Percentage: 0.01%
# Bonham: Count: 1, Percentage: 0.01%
# Bonne Terre: Count: 1, Percentage: 0.01%
# Bonners Ferry: Count: 1, Percentage: 0.01%
# Bonney Lake: Count: 1, Percentage: 0.01%
# Bono: Count: 1, Percentage: 0.01%
# Boone: Count: 2, Percentage: 0.02%
# Booneville: Count: 2, Percentage: 0.02%
# Boonsboro: Count: 1, Percentage: 0.01%
# Boonton: Count: 1, Percentage: 0.01%
# Boonton Township: Count: 1, Percentage: 0.01%
# Boonville: Count: 1, Percentage: 0.01%
# Boonville Village: Count: 1, Percentage: 0.01%
# Boothbay Harbor10: Count: 1, Percentage: 0.01%
# Bordentown City: Count: 1, Percentage: 0.01%
# Bordentown Township: Count: 1, Percentage: 0.01%
# Borger: Count: 1, Percentage: 0.01%
# Boscawen: Count: 1, Percentage: 0.01%
# Boscobel: Count: 1, Percentage: 0.01%
# Bosque Farms: Count: 1, Percentage: 0.01%
# Bossier City: Count: 1, Percentage: 0.01%
# Boston: Count: 1, Percentage: 0.01%
# Bothell: Count: 1, Percentage: 0.01%
# Boulder: Count: 2, Percentage: 0.02%
# Boulder City: Count: 1, Percentage: 0.01%
# Bound Brook: Count: 1, Percentage: 0.01%
# Bountiful: Count: 1, Percentage: 0.01%
# Bourbon: Count: 1, Percentage: 0.01%
# Bourbonnais: Count: 1, Percentage: 0.01%
# Bourne: Count: 1, Percentage: 0.01%
# Bovey: Count: 1, Percentage: 0.01%
# Bovina: Count: 1, Percentage: 0.01%
# Bow: Count: 1, Percentage: 0.01%
# Bow Mar: Count: 1, Percentage: 0.01%
# Bowdon: Count: 1, Percentage: 0.01%
# Bowie: Count: 2, Percentage: 0.02%
# Bowling Green: Count: 4, Percentage: 0.04%
# Bowman: Count: 1, Percentage: 0.01%
# Box Elder: Count: 1, Percentage: 0.01%
# Boxborough: Count: 1, Percentage: 0.01%
# Boxford: Count: 1, Percentage: 0.01%
# Boyceville: Count: 1, Percentage: 0.01%
# Boyd: Count: 1, Percentage: 0.01%
# Boyertown: Count: 1, Percentage: 0.01%
# Boykins: Count: 1, Percentage: 0.01%
# Boylston: Count: 1, Percentage: 0.01%
# Boyne City: Count: 1, Percentage: 0.01%
# Boynton Beach: Count: 1, Percentage: 0.01%
# Bozeman: Count: 1, Percentage: 0.01%
# Brackenridge: Count: 1, Percentage: 0.01%
# Bradbury: Count: 1, Percentage: 0.01%
# Braddock: Count: 1, Percentage: 0.01%
# Braddock Hills: Count: 1, Percentage: 0.01%
# Bradenton: Count: 1, Percentage: 0.01%
# Bradenton Beach: Count: 1, Percentage: 0.01%
# Bradford: Count: 4, Percentage: 0.04%
# Bradford Township: Count: 1, Percentage: 0.01%
# Bradley: Count: 1, Percentage: 0.01%
# Bradley Beach: Count: 1, Percentage: 0.01%
# Brady: Count: 1, Percentage: 0.01%
# Brady Lake: Count: 1, Percentage: 0.01%
# Braham: Count: 1, Percentage: 0.01%
# Braidwood: Count: 1, Percentage: 0.01%
# Brainerd: Count: 1, Percentage: 0.01%
# Braintree: Count: 1, Percentage: 0.01%
# Branchburg Township: Count: 1, Percentage: 0.01%
# Branchville: Count: 1, Percentage: 0.01%
# Brandenburg: Count: 1, Percentage: 0.01%
# Brandon: Count: 3, Percentage: 0.03%
# Brandon Township: Count: 1, Percentage: 0.01%
# Brandon-Fairwater: Count: 1, Percentage: 0.01%
# Branford: Count: 1, Percentage: 0.01%
# Branson: Count: 1, Percentage: 0.01%
# Branson West: Count: 1, Percentage: 0.01%
# Brant Town: Count: 1, Percentage: 0.01%
# Braselton: Count: 1, Percentage: 0.01%
# Braswell: Count: 1, Percentage: 0.01%
# Brattleboro: Count: 1, Percentage: 0.01%
# Brawley: Count: 1, Percentage: 0.01%
# Braymer: Count: 1, Percentage: 0.01%
# Brazoria: Count: 1, Percentage: 0.01%
# Brea: Count: 1, Percentage: 0.01%
# Breaux Bridge: Count: 1, Percentage: 0.01%
# Breckenridge: Count: 4, Percentage: 0.04%
# Breckenridge Hills: Count: 1, Percentage: 0.01%
# Brecknock Township, Berks County: Count: 1, Percentage: 0.01%
# Brecksville: Count: 1, Percentage: 0.01%
# Breese: Count: 1, Percentage: 0.01%
# Breezy Point: Count: 1, Percentage: 0.01%
# Breitung Township: Count: 1, Percentage: 0.01%
# Bremen: Count: 2, Percentage: 0.02%
# Bremerton: Count: 1, Percentage: 0.01%
# Bremond: Count: 1, Percentage: 0.01%
# Brenham: Count: 1, Percentage: 0.01%
# Brent: Count: 1, Percentage: 0.01%
# Brentwood: Count: 6, Percentage: 0.06%
# Brevard: Count: 1, Percentage: 0.01%
# Brewer10: Count: 1, Percentage: 0.01%
# Brewster: Count: 4, Percentage: 0.04%
# Brewton: Count: 1, Percentage: 0.01%
# Briar Creek Township: Count: 1, Percentage: 0.01%
# Briarcliff Manor Village: Count: 1, Percentage: 0.01%
# Briarcliffe Acres: Count: 1, Percentage: 0.01%
# Brick Township: Count: 1, Percentage: 0.01%
# Bridge City: Count: 1, Percentage: 0.01%
# Bridgeport: Count: 5, Percentage: 0.05%
# Bridgeport Township: Count: 1, Percentage: 0.01%
# Bridger: Count: 1, Percentage: 0.01%
# Bridgeton: Count: 2, Percentage: 0.02%
# Bridgeview: Count: 1, Percentage: 0.01%
# Bridgeville: Count: 2, Percentage: 0.02%
# Bridgewater: Count: 2, Percentage: 0.02%
# Bridgewater Township: Count: 1, Percentage: 0.01%
# Bridgman: Count: 1, Percentage: 0.01%
# Bridgton10: Count: 1, Percentage: 0.01%
# Brielle: Count: 1, Percentage: 0.01%
# Brier: Count: 1, Percentage: 0.01%
# Brigantine: Count: 1, Percentage: 0.01%
# Brigham City: Count: 1, Percentage: 0.01%
# Brighton: Count: 4, Percentage: 0.04%
# Brighton Town: Count: 1, Percentage: 0.01%
# Brighton Township: Count: 1, Percentage: 0.01%
# Brilliant: Count: 1, Percentage: 0.01%
# Brillion: Count: 1, Percentage: 0.01%
# Brimfield: Count: 1, Percentage: 0.01%
# Brimfield Township: Count: 1, Percentage: 0.01%
# Brinkley: Count: 1, Percentage: 0.01%
# Brisbane: Count: 1, Percentage: 0.01%
# Bristol: Count: 7, Percentage: 0.07%
# Bristol Bay Borough: Count: 1, Percentage: 0.01%
# Bristol Township: Count: 1, Percentage: 0.01%
# Bristow: Count: 1, Percentage: 0.01%
# Broadmoor: Count: 1, Percentage: 0.01%
# Broadview: Count: 1, Percentage: 0.01%
# Broadway: Count: 1, Percentage: 0.01%
# Brockport Village: Count: 1, Percentage: 0.01%
# Brockton: Count: 1, Percentage: 0.01%
# Brockway: Count: 1, Percentage: 0.01%
# Brodhead: Count: 2, Percentage: 0.02%
# Broken Arrow: Count: 1, Percentage: 0.01%
# Broken Bow: Count: 2, Percentage: 0.02%
# Bronson: Count: 2, Percentage: 0.02%
# Brookfield: Count: 4, Percentage: 0.04%
# Brookfield Township: Count: 1, Percentage: 0.01%
# Brookhaven: Count: 2, Percentage: 0.02%
# Brookings: Count: 2, Percentage: 0.02%
# Brookland: Count: 1, Percentage: 0.01%
# Brooklawn: Count: 1, Percentage: 0.01%
# Brooklet: Count: 1, Percentage: 0.01%
# Brookline: Count: 1, Percentage: 0.01%
# Brookline4: Count: 1, Percentage: 0.01%
# Brooklyn: Count: 2, Percentage: 0.02%
# Brooklyn Center: Count: 1, Percentage: 0.01%
# Brooklyn Park: Count: 1, Percentage: 0.01%
# Brookneal: Count: 1, Percentage: 0.01%
# Brookshire: Count: 1, Percentage: 0.01%
# Brookside Village: Count: 1, Percentage: 0.01%
# Brooksville: Count: 2, Percentage: 0.02%
# Brookville: Count: 2, Percentage: 0.02%
# Brookwood: Count: 1, Percentage: 0.01%
# Broomfield: Count: 1, Percentage: 0.01%
# Broussard: Count: 1, Percentage: 0.01%
# Brown City: Count: 1, Percentage: 0.01%
# Brown Deer: Count: 1, Percentage: 0.01%
# Brownfield: Count: 1, Percentage: 0.01%
# Brownsburg: Count: 1, Percentage: 0.01%
# Brownstown: Count: 1, Percentage: 0.01%
# Brownstown Township: Count: 1, Percentage: 0.01%
# Brownsville: Count: 5, Percentage: 0.05%
# Brownton: Count: 1, Percentage: 0.01%
# Brownville Village: Count: 1, Percentage: 0.01%
# Brownville10: Count: 1, Percentage: 0.01%
# Brownwood: Count: 1, Percentage: 0.01%
# Bruceton: Count: 1, Percentage: 0.01%
# Brunswick: Count: 3, Percentage: 0.03%
# Brunswick Hills Township: Count: 1, Percentage: 0.01%
# Brunswick10: Count: 1, Percentage: 0.01%
# Brush: Count: 1, Percentage: 0.01%
# Brusly: Count: 1, Percentage: 0.01%
# Bryan: Count: 1, Percentage: 0.01%
# Bryant: Count: 1, Percentage: 0.01%
# Bryn Athyn: Count: 1, Percentage: 0.01%
# Buchanan: Count: 2, Percentage: 0.02%
# Buckeye: Count: 1, Percentage: 0.01%
# Buckhannon: Count: 1, Percentage: 0.01%
# Buckingham Township: Count: 1, Percentage: 0.01%
# Buckley: Count: 1, Percentage: 0.01%
# Bucklin: Count: 2, Percentage: 0.02%
# Buckner: Count: 1, Percentage: 0.01%
# Bucksport10: Count: 1, Percentage: 0.01%
# Bucyrus: Count: 1, Percentage: 0.01%
# Buda: Count: 1, Percentage: 0.01%
# Buellton: Count: 1, Percentage: 0.01%
# Buena: Count: 1, Percentage: 0.01%
# Buena Park: Count: 1, Percentage: 0.01%
# Buena Vista: Count: 3, Percentage: 0.03%
# Buena Vista Township: Count: 1, Percentage: 0.01%
# Buffalo: Count: 5, Percentage: 0.05%
# Buffalo Grove: Count: 1, Percentage: 0.01%
# Buffalo Lake: Count: 1, Percentage: 0.01%
# Buffalo Township: Count: 1, Percentage: 0.01%
# Buffalo Valley Regional: Count: 1, Percentage: 0.01%
# Buhl: Count: 1, Percentage: 0.01%
# Bull Shoals: Count: 1, Percentage: 0.01%
# Bullard: Count: 1, Percentage: 0.01%
# Bullhead City: Count: 1, Percentage: 0.01%
# Bulverde: Count: 1, Percentage: 0.01%
# Bunker Hill: Count: 1, Percentage: 0.01%
# Bunkie4: Count: 1, Percentage: 0.01%
# Bunnell: Count: 1, Percentage: 0.01%
# Burbank: Count: 2, Percentage: 0.02%
# Burden: Count: 1, Percentage: 0.01%
# Burgaw: Count: 1, Percentage: 0.01%
# Burgettstown: Count: 1, Percentage: 0.01%
# Burien: Count: 1, Percentage: 0.01%
# Burkburnett: Count: 1, Percentage: 0.01%
# Burke: Count: 1, Percentage: 0.01%
# Burkesville: Count: 1, Percentage: 0.01%
# Burkeville: Count: 1, Percentage: 0.01%
# Burleson: Count: 1, Percentage: 0.01%
# Burlingame: Count: 1, Percentage: 0.01%
# Burlington: Count: 8, Percentage: 0.08%
# Burlington City: Count: 1, Percentage: 0.01%
# Burlington Township: Count: 1, Percentage: 0.01%
# Burnet: Count: 1, Percentage: 0.01%
# Burnettown: Count: 1, Percentage: 0.01%
# Burnham: Count: 1, Percentage: 0.01%
# Burns: Count: 1, Percentage: 0.01%
# Burns7: Count: 1, Percentage: 0.01%
# Burnside: Count: 1, Percentage: 0.01%
# Burnsville: Count: 1, Percentage: 0.01%
# Burr Ridge: Count: 1, Percentage: 0.01%
# Burrillville: Count: 1, Percentage: 0.01%
# Burton: Count: 1, Percentage: 0.01%
# Bushkill Township: Count: 1, Percentage: 0.01%
# Butler: Count: 6, Percentage: 0.06%
# Butler Township: Count: 1, Percentage: 0.01%
# Butler Township, Butler County: Count: 1, Percentage: 0.01%
# Butler Township, Luzerne County: Count: 1, Percentage: 0.01%
# Butler Township, Schuylkill County: Count: 1, Percentage: 0.01%
# Butner: Count: 1, Percentage: 0.01%
# Butterfield Village: Count: 1, Percentage: 0.01%
# Buxton10: Count: 1, Percentage: 0.01%
# Byhalia: Count: 1, Percentage: 0.01%
# Byram Township: Count: 1, Percentage: 0.01%
# Byrnes Mill: Count: 1, Percentage: 0.01%
# Byron: Count: 2, Percentage: 0.02%
# Cabool: Count: 1, Percentage: 0.01%
# Cabot: Count: 1, Percentage: 0.01%
# Cache: Count: 1, Percentage: 0.01%
# Cactus: Count: 1, Percentage: 0.01%
# Caddo: Count: 1, Percentage: 0.01%
# Caddo Mills: Count: 1, Percentage: 0.01%
# Caddo Valley: Count: 1, Percentage: 0.01%
# Cadillac: Count: 1, Percentage: 0.01%
# Cadiz: Count: 2, Percentage: 0.02%
# Caernarvon Township, Berks County: Count: 1, Percentage: 0.01%
# Cahokia: Count: 1, Percentage: 0.01%
# Cairo: Count: 2, Percentage: 0.02%
# Cairo Town: Count: 1, Percentage: 0.01%
# Calabasas: Count: 1, Percentage: 0.01%
# Calais10: Count: 1, Percentage: 0.01%
# Caldwell: Count: 3, Percentage: 0.03%
# Caledonia: Count: 2, Percentage: 0.02%
# Caledonia Village: Count: 1, Percentage: 0.01%
# Calera: Count: 1, Percentage: 0.01%
# Calexico: Count: 1, Percentage: 0.01%
# Calhan: Count: 1, Percentage: 0.01%
# Calhoun: Count: 2, Percentage: 0.02%
# Califon: Count: 1, Percentage: 0.01%
# California: Count: 2, Percentage: 0.02%
# California City: Count: 1, Percentage: 0.01%
# Calimesa: Count: 1, Percentage: 0.01%
# Calistoga: Count: 1, Percentage: 0.01%
# Callery: Count: 1, Percentage: 0.01%
# Caln Township: Count: 1, Percentage: 0.01%
# Calumet: Count: 1, Percentage: 0.01%
# Calumet City: Count: 1, Percentage: 0.01%
# Calvert: Count: 1, Percentage: 0.01%
# Calvert City: Count: 1, Percentage: 0.01%
# Calverton Park: Count: 1, Percentage: 0.01%
# Camanche: Count: 1, Percentage: 0.01%
# Camarillo: Count: 1, Percentage: 0.01%
# Camas: Count: 1, Percentage: 0.01%
# Cambria: Count: 1, Percentage: 0.01%
# Cambria Township: Count: 1, Percentage: 0.01%
# Cambridge: Count: 5, Percentage: 0.05%
# Cambridge Springs: Count: 1, Percentage: 0.01%
# Cambridge Township: Count: 1, Percentage: 0.01%
# Cambridge Village: Count: 1, Percentage: 0.01%
# Camden: Count: 5, Percentage: 0.05%
# Camden Village: Count: 1, Percentage: 0.01%
# Camden10: Count: 1, Percentage: 0.01%
# Camdenton7: Count: 1, Percentage: 0.01%
# Cameron: Count: 3, Percentage: 0.03%
# Camilla: Count: 1, Percentage: 0.01%
# Camillus Town and Village: Count: 1, Percentage: 0.01%
# Cammack Village: Count: 1, Percentage: 0.01%
# Camp Hill: Count: 2, Percentage: 0.02%
# Camp Point: Count: 1, Percentage: 0.01%
# Camp Verde: Count: 1, Percentage: 0.01%
# Campbell: Count: 3, Percentage: 0.03%
# Campbell Township: Count: 1, Percentage: 0.01%
# Campbellsburg: Count: 1, Percentage: 0.01%
# Campbellsport: Count: 1, Percentage: 0.01%
# Campbellsville: Count: 1, Percentage: 0.01%
# Campo: Count: 1, Percentage: 0.01%
# Campobello: Count: 1, Percentage: 0.01%
# Campton: Count: 1, Percentage: 0.01%
# Campton Hills: Count: 1, Percentage: 0.01%
# Canajoharie Village: Count: 1, Percentage: 0.01%
# Canal Fulton: Count: 1, Percentage: 0.01%
# Canandaigua: Count: 1, Percentage: 0.01%
# Canastota Village: Count: 1, Percentage: 0.01%
# Canby: Count: 2, Percentage: 0.02%
# Candia: Count: 1, Percentage: 0.01%
# Caney: Count: 1, Percentage: 0.01%
# Caneyville: Count: 1, Percentage: 0.01%
# Canfield: Count: 1, Percentage: 0.01%
# Canisteo Village: Count: 1, Percentage: 0.01%
# Cannon Beach7: Count: 1, Percentage: 0.01%
# Cannon Falls: Count: 1, Percentage: 0.01%
# Canon: Count: 1, Percentage: 0.01%
# Canonsburg: Count: 1, Percentage: 0.01%
# Canterbury: Count: 1, Percentage: 0.01%
# Canton: Count: 9, Percentage: 0.09%
# Canton Township: Count: 1, Percentage: 0.01%
# Canton Village: Count: 1, Percentage: 0.01%
# Canyon Lake: Count: 1, Percentage: 0.01%
# Canyon7: Count: 1, Percentage: 0.01%
# Capac: Count: 1, Percentage: 0.01%
# Cape Carteret: Count: 1, Percentage: 0.01%
# Cape Charles: Count: 1, Percentage: 0.01%
# Cape Coral: Count: 1, Percentage: 0.01%
# Cape Elizabeth10: Count: 1, Percentage: 0.01%
# Cape Girardeau: Count: 1, Percentage: 0.01%
# Cape May: Count: 1, Percentage: 0.01%
# Cape May Point: Count: 1, Percentage: 0.01%
# Cape Vincent Village: Count: 1, Percentage: 0.01%
# Capitan: Count: 1, Percentage: 0.01%
# Capitol Heights: Count: 1, Percentage: 0.01%
# Capitola: Count: 1, Percentage: 0.01%
# Caraway: Count: 1, Percentage: 0.01%
# Carbon Hill: Count: 1, Percentage: 0.01%
# Carbondale: Count: 3, Percentage: 0.03%
# Cardwell: Count: 1, Percentage: 0.01%
# Carencro: Count: 1, Percentage: 0.01%
# Carey: Count: 1, Percentage: 0.01%
# Caribou10: Count: 1, Percentage: 0.01%
# Carl Junction: Count: 1, Percentage: 0.01%
# Carleton: Count: 1, Percentage: 0.01%
# Carlin: Count: 1, Percentage: 0.01%
# Carlinville: Count: 1, Percentage: 0.01%
# Carlisle: Count: 6, Percentage: 0.06%
# Carlsbad: Count: 2, Percentage: 0.02%
# Carlstadt: Count: 1, Percentage: 0.01%
# Carlton: Count: 1, Percentage: 0.01%
# Carlyle: Count: 1, Percentage: 0.01%
# Carmel: Count: 2, Percentage: 0.02%
# Carmel Town: Count: 1, Percentage: 0.01%
# Carnation: Count: 1, Percentage: 0.01%
# Carnegie: Count: 2, Percentage: 0.02%
# Carney: Count: 1, Percentage: 0.01%
# Carney's Point Township: Count: 1, Percentage: 0.01%
# Caro: Count: 1, Percentage: 0.01%
# Carol Stream: Count: 1, Percentage: 0.01%
# Carpentersville: Count: 1, Percentage: 0.01%
# Carpinteria: Count: 1, Percentage: 0.01%
# Carrabassett Valley: Count: 1, Percentage: 0.01%
# Carrabelle: Count: 1, Percentage: 0.01%
# Carrboro: Count: 1, Percentage: 0.01%
# Carrington: Count: 1, Percentage: 0.01%
# Carrizozo: Count: 1, Percentage: 0.01%
# Carroll: Count: 2, Percentage: 0.02%
# Carroll Town: Count: 1, Percentage: 0.01%
# Carroll Township: Count: 1, Percentage: 0.01%
# Carroll Township, Washington County: Count: 1, Percentage: 0.01%
# Carroll Township, York County: Count: 1, Percentage: 0.01%
# Carroll Valley: Count: 1, Percentage: 0.01%
# Carrollton: Count: 6, Percentage: 0.06%
# Carrollton Township: Count: 1, Percentage: 0.01%
# Carrolltown: Count: 1, Percentage: 0.01%
# Carson: Count: 1, Percentage: 0.01%
# Carson City: Count: 1, Percentage: 0.01%
# Carter Lake: Count: 1, Percentage: 0.01%
# Carteret: Count: 1, Percentage: 0.01%
# Carterville: Count: 2, Percentage: 0.02%
# Carthage: Count: 5, Percentage: 0.05%
# Carthage Village: Count: 1, Percentage: 0.01%
# Caruthersville: Count: 1, Percentage: 0.01%
# Carver: Count: 1, Percentage: 0.01%
# Cary: Count: 2, Percentage: 0.02%
# Caryville: Count: 1, Percentage: 0.01%
# Casa Grande: Count: 1, Percentage: 0.01%
# Cascade: Count: 1, Percentage: 0.01%
# Caseville: Count: 1, Percentage: 0.01%
# Caseyville: Count: 1, Percentage: 0.01%
# Cashion: Count: 1, Percentage: 0.01%
# Cashton: Count: 1, Percentage: 0.01%
# Casper: Count: 1, Percentage: 0.01%
# Caspian-Gaastra: Count: 1, Percentage: 0.01%
# Cass City: Count: 1, Percentage: 0.01%
# Cass Township: Count: 1, Percentage: 0.01%
# Casselberry: Count: 1, Percentage: 0.01%
# Cassopolis: Count: 1, Percentage: 0.01%
# Cassville: Count: 1, Percentage: 0.01%
# Castle Hills: Count: 1, Percentage: 0.01%
# Castle Rock: Count: 2, Percentage: 0.02%
# Castle Shannon: Count: 1, Percentage: 0.01%
# Castroville: Count: 1, Percentage: 0.01%
# Catasauqua: Count: 1, Percentage: 0.01%
# Catawissa: Count: 1, Percentage: 0.01%
# Cathedral City: Count: 1, Percentage: 0.01%
# Catlettsburg: Count: 1, Percentage: 0.01%
# Catlin: Count: 1, Percentage: 0.01%
# Catoosa: Count: 1, Percentage: 0.01%
# Cattaraugus Village: Count: 1, Percentage: 0.01%
# Cavalier: Count: 1, Percentage: 0.01%
# Cave City: Count: 1, Percentage: 0.01%
# Cave Spring: Count: 1, Percentage: 0.01%
# Cave Springs: Count: 1, Percentage: 0.01%
# Cayce: Count: 1, Percentage: 0.01%
# Cayuga Heights Village: Count: 1, Percentage: 0.01%
# Cazenovia Village: Count: 1, Percentage: 0.01%
# Cecil Township: Count: 1, Percentage: 0.01%
# Cedar City: Count: 1, Percentage: 0.01%
# Cedar Falls: Count: 1, Percentage: 0.01%
# Cedar Grove Township: Count: 1, Percentage: 0.01%
# Cedar Hill: Count: 1, Percentage: 0.01%
# Cedar Lake: Count: 1, Percentage: 0.01%
# Cedar Park: Count: 1, Percentage: 0.01%
# Cedar Rapids: Count: 1, Percentage: 0.01%
# Cedarburg: Count: 1, Percentage: 0.01%
# Cedartown: Count: 1, Percentage: 0.01%
# Celina: Count: 2, Percentage: 0.02%
# Centennial Lakes: Count: 1, Percentage: 0.01%
# Center: Count: 2, Percentage: 0.02%
# Center Harbor: Count: 1, Percentage: 0.01%
# Center Hill: Count: 1, Percentage: 0.01%
# Center Line: Count: 1, Percentage: 0.01%
# Center Township: Count: 1, Percentage: 0.01%
# Center7: Count: 1, Percentage: 0.01%
# Centerfield: Count: 1, Percentage: 0.01%
# Centerton: Count: 1, Percentage: 0.01%
# Centertown: Count: 1, Percentage: 0.01%
# Centerville: Count: 5, Percentage: 0.05%
# Central Berks Regional: Count: 1, Percentage: 0.01%
# Central Bucks Regional: Count: 1, Percentage: 0.01%
# Central City: Count: 2, Percentage: 0.02%
# Central Falls: Count: 1, Percentage: 0.01%
# Central Lake: Count: 1, Percentage: 0.01%
# Central Marin: Count: 1, Percentage: 0.01%
# Central Point: Count: 1, Percentage: 0.01%
# Central Square Village: Count: 1, Percentage: 0.01%
# Centralia: Count: 2, Percentage: 0.02%
# Centre: Count: 1, Percentage: 0.01%
# Centre Island Village: Count: 1, Percentage: 0.01%
# Centreville: Count: 2, Percentage: 0.02%
# Ceredo: Count: 1, Percentage: 0.01%
# Ceres: Count: 1, Percentage: 0.01%
# Cerritos: Count: 1, Percentage: 0.01%
# Chadron: Count: 1, Percentage: 0.01%
# Chaffee: Count: 1, Percentage: 0.01%
# Chagrin Falls: Count: 1, Percentage: 0.01%
# Challis: Count: 1, Percentage: 0.01%
# Chamberlain: Count: 1, Percentage: 0.01%
# Chambersburg: Count: 1, Percentage: 0.01%
# Chamblee: Count: 1, Percentage: 0.01%
# Champaign: Count: 1, Percentage: 0.01%
# Champlin: Count: 1, Percentage: 0.01%
# Chandler: Count: 2, Percentage: 0.02%
# Channahon: Count: 1, Percentage: 0.01%
# Chapel Hill: Count: 2, Percentage: 0.02%
# Chapin: Count: 1, Percentage: 0.01%
# Chardon: Count: 1, Percentage: 0.01%
# Chariton: Count: 1, Percentage: 0.01%
# Charlack: Count: 1, Percentage: 0.01%
# Charleroi Regional: Count: 1, Percentage: 0.01%
# Charles City: Count: 1, Percentage: 0.01%
# Charles Town: Count: 1, Percentage: 0.01%
# Charleston: Count: 5, Percentage: 0.05%
# Charlestown: Count: 3, Percentage: 0.03%
# Charlevoix: Count: 1, Percentage: 0.01%
# Charlotte: Count: 1, Percentage: 0.01%
# Charlotte-Mecklenburg: Count: 1, Percentage: 0.01%
# Charlottesville: Count: 1, Percentage: 0.01%
# Charlton: Count: 1, Percentage: 0.01%
# Chartiers Township: Count: 1, Percentage: 0.01%
# Chase City: Count: 1, Percentage: 0.01%
# Chaska: Count: 1, Percentage: 0.01%
# Chatham: Count: 4, Percentage: 0.04%
# Chatham Township: Count: 1, Percentage: 0.01%
# Chatom: Count: 1, Percentage: 0.01%
# Chatsworth: Count: 1, Percentage: 0.01%
# Chattahoochee: Count: 1, Percentage: 0.01%
# Chattahoochee Hills: Count: 1, Percentage: 0.01%
# Chattanooga: Count: 1, Percentage: 0.01%
# Cheboygan: Count: 1, Percentage: 0.01%
# Checotah: Count: 1, Percentage: 0.01%
# Cheektowaga Town: Count: 1, Percentage: 0.01%
# Chehalis: Count: 1, Percentage: 0.01%
# Chelmsford: Count: 1, Percentage: 0.01%
# Chelsea: Count: 3, Percentage: 0.03%
# Cheltenham Township: Count: 1, Percentage: 0.01%
# Chenequa: Count: 1, Percentage: 0.01%
# Cheney: Count: 1, Percentage: 0.01%
# Chenoa: Count: 1, Percentage: 0.01%
# Cheraw: Count: 1, Percentage: 0.01%
# Cherokee: Count: 2, Percentage: 0.02%
# Cherokee Village: Count: 1, Percentage: 0.01%
# ...
# West Brandywine Township: Count: 1, Percentage: 0.01%
# West Bridgewater: Count: 1, Percentage: 0.01%
# West Buechel: Count: 1, Percentage: 0.01%
# West Burlington4: Count: 1, Percentage: 0.01%
# West Caldwell Township: Count: 1, Percentage: 0.01%
# West Caln Township: Count: 1, Percentage: 0.01%
# West Cape May: Count: 1, Percentage: 0.01%
# West Carroll Township: Count: 1, Percentage: 0.01%
# West Carrollton: Count: 1, Percentage: 0.01%
# West Carthage Village: Count: 1, Percentage: 0.01%
# West Chester: Count: 1, Percentage: 0.01%
# West Chester Township: Count: 1, Percentage: 0.01%
# West Chicago: Count: 1, Percentage: 0.01%
# West City: Count: 1, Percentage: 0.01%
# West Cocalico Township: Count: 1, Percentage: 0.01%
# West Columbia: Count: 1, Percentage: 0.01%
# West Concord: Count: 1, Percentage: 0.01%
# West Conshohocken: Count: 1, Percentage: 0.01%
# West Cornwall Township: Count: 1, Percentage: 0.01%
# West Covina: Count: 1, Percentage: 0.01%
# West Deer Township: Count: 1, Percentage: 0.01%
# West Deptford Township: Count: 1, Percentage: 0.01%
# West Des Moines: Count: 1, Percentage: 0.01%
# West Dundee: Count: 1, Percentage: 0.01%
# West Earl Township: Count: 1, Percentage: 0.01%
# West Fallowfield Township: Count: 1, Percentage: 0.01%
# West Fargo: Count: 1, Percentage: 0.01%
# West Fork: Count: 1, Percentage: 0.01%
# West Frankfort: Count: 1, Percentage: 0.01%
# West Goshen Township: Count: 1, Percentage: 0.01%
# West Greenwich: Count: 1, Percentage: 0.01%
# West Hartford: Count: 1, Percentage: 0.01%
# West Haven: Count: 1, Percentage: 0.01%
# West Hempfield Township: Count: 1, Percentage: 0.01%
# West Hennepin: Count: 1, Percentage: 0.01%
# West Hills Regional: Count: 1, Percentage: 0.01%
# West Hollywood: Count: 1, Percentage: 0.01%
# West Homestead: Count: 1, Percentage: 0.01%
# West Jefferson: Count: 2, Percentage: 0.02%
# West Jordan: Count: 1, Percentage: 0.01%
# West Kittanning: Count: 1, Percentage: 0.01%
# West Lafayette: Count: 2, Percentage: 0.02%
# West Lake Hills: Count: 1, Percentage: 0.01%
# West Lebanon Township: Count: 1, Percentage: 0.01%
# West Leechburg: Count: 1, Percentage: 0.01%
# West Liberty: Count: 4, Percentage: 0.04%
# West Long Branch: Count: 1, Percentage: 0.01%
# West Manchester Township: Count: 1, Percentage: 0.01%
# West Manheim Township: Count: 1, Percentage: 0.01%
# West Mead Township: Count: 1, Percentage: 0.01%
# West Melbourne: Count: 1, Percentage: 0.01%
# West Memphis: Count: 1, Percentage: 0.01%
# West Miami: Count: 1, Percentage: 0.01%
# West Mifflin: Count: 1, Percentage: 0.01%
# West Milford Township: Count: 1, Percentage: 0.01%
# West Milwaukee: Count: 1, Percentage: 0.01%
# West Monroe: Count: 1, Percentage: 0.01%
# West New York: Count: 1, Percentage: 0.01%
# West Newbury: Count: 1, Percentage: 0.01%
# West Newton: Count: 1, Percentage: 0.01%
# West Norriton Township: Count: 1, Percentage: 0.01%
# West Nottingham Township: Count: 1, Percentage: 0.01%
# West Orange: Count: 2, Percentage: 0.02%
# West Palm Beach: Count: 1, Percentage: 0.01%
# West Park: Count: 1, Percentage: 0.01%
# West Pelzer: Count: 1, Percentage: 0.01%
# West Penn Township: Count: 1, Percentage: 0.01%
# West Pittston: Count: 1, Percentage: 0.01%
# West Plains: Count: 1, Percentage: 0.01%
# West Point: Count: 5, Percentage: 0.05%
# West Pottsgrove Township: Count: 1, Percentage: 0.01%
# West Reading: Count: 1, Percentage: 0.01%
# West Richland: Count: 1, Percentage: 0.01%
# West Sacramento: Count: 1, Percentage: 0.01%
# West Sadsbury Township: Count: 1, Percentage: 0.01%
# West Salem: Count: 1, Percentage: 0.01%
# West Salem Township: Count: 1, Percentage: 0.01%
# West Seneca Town: Count: 1, Percentage: 0.01%
# West Shore Regional: Count: 1, Percentage: 0.01%
# West Siloam Springs: Count: 1, Percentage: 0.01%
# West Springfield: Count: 1, Percentage: 0.01%
# West St. Paul: Count: 1, Percentage: 0.01%
# West Tisbury: Count: 1, Percentage: 0.01%
# West Union: Count: 2, Percentage: 0.02%
# West University Place: Count: 1, Percentage: 0.01%
# West Valley: Count: 1, Percentage: 0.01%
# West View: Count: 1, Percentage: 0.01%
# West Vincent Township: Count: 1, Percentage: 0.01%
# West Warwick: Count: 1, Percentage: 0.01%
# West Wendover: Count: 1, Percentage: 0.01%
# West Wildwood: Count: 1, Percentage: 0.01%
# West Windsor Township: Count: 1, Percentage: 0.01%
# West Yellowstone: Count: 1, Percentage: 0.01%
# Westampton Township: Count: 1, Percentage: 0.01%
# Westborough: Count: 1, Percentage: 0.01%
# Westbrook10: Count: 1, Percentage: 0.01%
# Westby: Count: 1, Percentage: 0.01%
# Westchester: Count: 1, Percentage: 0.01%
# Westerly: Count: 1, Percentage: 0.01%
# Western Berks Regional: Count: 1, Percentage: 0.01%
# Western Springs: Count: 1, Percentage: 0.01%
# Westerville: Count: 1, Percentage: 0.01%
# Westfield: Count: 4, Percentage: 0.04%
# Westfield Village: Count: 1, Percentage: 0.01%
# Westford: Count: 1, Percentage: 0.01%
# Westhampton Beach Village: Count: 1, Percentage: 0.01%
# Westlake: Count: 1, Percentage: 0.01%
# Westlake Village: Count: 1, Percentage: 0.01%
# Westland: Count: 1, Percentage: 0.01%
# Westminster: Count: 5, Percentage: 0.05%
# Westmont: Count: 1, Percentage: 0.01%
# Westmoreland: Count: 1, Percentage: 0.01%
# Westmorland: Count: 1, Percentage: 0.01%
# Weston: Count: 5, Percentage: 0.05%
# Westover Hills: Count: 1, Percentage: 0.01%
# Westport: Count: 3, Percentage: 0.03%
# Westtown-East Goshen Regional: Count: 1, Percentage: 0.01%
# Westville: Count: 3, Percentage: 0.03%
# Westwego: Count: 1, Percentage: 0.01%
# Westwood: Count: 3, Percentage: 0.03%
# Westworth: Count: 1, Percentage: 0.01%
# Wetumka: Count: 1, Percentage: 0.01%
# Wetumpka: Count: 1, Percentage: 0.01%
# Wewoka: Count: 1, Percentage: 0.01%
# Weymouth: Count: 1, Percentage: 0.01%
# Wharton: Count: 2, Percentage: 0.02%
# Whately: Count: 1, Percentage: 0.01%
# Wheat Ridge: Count: 1, Percentage: 0.01%
# Wheatland: Count: 2, Percentage: 0.02%
# Wheaton: Count: 3, Percentage: 0.03%
# Wheeling: Count: 2, Percentage: 0.02%
# Wheelwright: Count: 1, Percentage: 0.01%
# Whigham: Count: 1, Percentage: 0.01%
# Whispering Pines: Count: 1, Percentage: 0.01%
# Whitaker Borough: Count: 1, Percentage: 0.01%
# White Bear Lake: Count: 1, Percentage: 0.01%
# White Bluff: Count: 1, Percentage: 0.01%
# White Castle: Count: 1, Percentage: 0.01%
# White Cloud: Count: 1, Percentage: 0.01%
# White Hall: Count: 3, Percentage: 0.03%
# White House: Count: 1, Percentage: 0.01%
# White Lake: Count: 1, Percentage: 0.01%
# White Lake Township: Count: 1, Percentage: 0.01%
# White Oak: Count: 2, Percentage: 0.02%
# White Pigeon: Count: 1, Percentage: 0.01%
# White Pine: Count: 1, Percentage: 0.01%
# White Plains: Count: 1, Percentage: 0.01%
# White Salmon: Count: 1, Percentage: 0.01%
# White Settlement: Count: 1, Percentage: 0.01%
# White Springs: Count: 1, Percentage: 0.01%
# White Stone: Count: 1, Percentage: 0.01%
# Whitefish: Count: 1, Percentage: 0.01%
# Whitefish Bay: Count: 1, Percentage: 0.01%
# Whitehall: Count: 4, Percentage: 0.04%
# Whitehall Township: Count: 1, Percentage: 0.01%
# Whitehouse: Count: 1, Percentage: 0.01%
# Whitehouse7: Count: 1, Percentage: 0.01%
# Whitemarsh Township: Count: 1, Percentage: 0.01%
# Whitesboro: Count: 1, Percentage: 0.01%
# Whitesboro Village: Count: 1, Percentage: 0.01%
# Whitesburg: Count: 2, Percentage: 0.02%
# Whitestown: Count: 1, Percentage: 0.01%
# Whitestown Town: Count: 1, Percentage: 0.01%
# Whiteville: Count: 1, Percentage: 0.01%
# Whitewater: Count: 1, Percentage: 0.01%
# Whitewood: Count: 1, Percentage: 0.01%
# Whiting: Count: 1, Percentage: 0.01%
# Whitman: Count: 1, Percentage: 0.01%
# Whitmire: Count: 1, Percentage: 0.01%
# Whitney: Count: 1, Percentage: 0.01%
# Whitpain Township: Count: 1, Percentage: 0.01%
# Whittier: Count: 1, Percentage: 0.01%
# Whitwell: Count: 1, Percentage: 0.01%
# Wichita: Count: 1, Percentage: 0.01%
# Wichita Falls: Count: 1, Percentage: 0.01%
# Wickenburg: Count: 1, Percentage: 0.01%
# Wickliffe: Count: 1, Percentage: 0.01%
# Wiggins: Count: 1, Percentage: 0.01%
# Wilber: Count: 1, Percentage: 0.01%
# Wilbraham: Count: 1, Percentage: 0.01%
# Wilburton: Count: 1, Percentage: 0.01%
# Wild Rose: Count: 1, Percentage: 0.01%
# Wilder: Count: 2, Percentage: 0.02%
# Wildomar: Count: 1, Percentage: 0.01%
# Wildwood: Count: 2, Percentage: 0.02%
# Wildwood Crest: Count: 1, Percentage: 0.01%
# Wilkes-Barre Township: Count: 1, Percentage: 0.01%
# Wilkesboro: Count: 1, Percentage: 0.01%
# Wilkins Township: Count: 1, Percentage: 0.01%
# Wilkinsburg: Count: 1, Percentage: 0.01%
# Willacoochee: Count: 1, Percentage: 0.01%
# Willard: Count: 3, Percentage: 0.03%
# Willcox: Count: 1, Percentage: 0.01%
# Williams: Count: 2, Percentage: 0.02%
# Williams Bay: Count: 1, Percentage: 0.01%
# Williamsburg: Count: 6, Percentage: 0.06%
# Williamson: Count: 1, Percentage: 0.01%
# Williamsport: Count: 1, Percentage: 0.01%
# Williamston: Count: 2, Percentage: 0.02%
# Williamstown: Count: 3, Percentage: 0.03%
# Willimantic: Count: 1, Percentage: 0.01%
# Willimantic10: Count: 1, Percentage: 0.01%
# Willingboro Township: Count: 1, Percentage: 0.01%
# Willis: Count: 1, Percentage: 0.01%
# Williston: Count: 3, Percentage: 0.03%
# Willits: Count: 1, Percentage: 0.01%
# Willmar: Count: 1, Percentage: 0.01%
# Willoughby: Count: 1, Percentage: 0.01%
# Willow Park: Count: 1, Percentage: 0.01%
# Willow Springs: Count: 2, Percentage: 0.02%
# Willowbrook: Count: 1, Percentage: 0.01%
# Willows: Count: 1, Percentage: 0.01%
# Wills Point: Count: 1, Percentage: 0.01%
# Wilmer: Count: 1, Percentage: 0.01%
# Wilmette: Count: 1, Percentage: 0.01%
# Wilmington: Count: 6, Percentage: 0.06%
# Wilmore: Count: 1, Percentage: 0.01%
# Wilson: Count: 3, Percentage: 0.03%
# Wilton: Count: 4, Percentage: 0.04%
# Wilton Manors: Count: 1, Percentage: 0.01%
# Wilton10: Count: 1, Percentage: 0.01%
# Winchendon: Count: 1, Percentage: 0.01%
# Winchester: Count: 7, Percentage: 0.07%
# Windber: Count: 1, Percentage: 0.01%
# Windcrest: Count: 1, Percentage: 0.01%
# Winder: Count: 1, Percentage: 0.01%
# Windermere: Count: 1, Percentage: 0.01%
# Windham: Count: 2, Percentage: 0.02%
# Windham Town: Count: 1, Percentage: 0.01%
# Windham10: Count: 1, Percentage: 0.01%
# Windom: Count: 1, Percentage: 0.01%
# Windsor: Count: 5, Percentage: 0.05%
# Windsor Heights: Count: 1, Percentage: 0.01%
# Windsor Locks: Count: 1, Percentage: 0.01%
# Winfield: Count: 6, Percentage: 0.06%
# Winfield Township: Count: 1, Percentage: 0.01%
# Wingo: Count: 1, Percentage: 0.01%
# Wink: Count: 1, Percentage: 0.01%
# Winlock: Count: 1, Percentage: 0.01%
# Winnebago: Count: 2, Percentage: 0.02%
# Winneconne: Count: 1, Percentage: 0.01%
# Winnemucca: Count: 1, Percentage: 0.01%
# Winner: Count: 1, Percentage: 0.01%
# Winnetka: Count: 1, Percentage: 0.01%
# Winnfield: Count: 1, Percentage: 0.01%
# Winnsboro: Count: 2, Percentage: 0.02%
# Winona: Count: 2, Percentage: 0.02%
# Winooski: Count: 1, Percentage: 0.01%
# Winslow: Count: 2, Percentage: 0.02%
# Winslow Township: Count: 1, Percentage: 0.01%
# Winsted: Count: 1, Percentage: 0.01%
# Winston: Count: 1, Percentage: 0.01%
# Winter Garden: Count: 1, Percentage: 0.01%
# Winter Harbor10: Count: 1, Percentage: 0.01%
# Winter Haven: Count: 1, Percentage: 0.01%
# Winter Park: Count: 1, Percentage: 0.01%
# Winter Springs: Count: 1, Percentage: 0.01%
# Winters: Count: 2, Percentage: 0.02%
# Winterset: Count: 1, Percentage: 0.01%
# Wintersville: Count: 1, Percentage: 0.01%
# Winterville: Count: 2, Percentage: 0.02%
# Winthrop: Count: 2, Percentage: 0.02%
# Winthrop Harbor: Count: 1, Percentage: 0.01%
# Winthrop10: Count: 1, Percentage: 0.01%
# Wiscasset10: Count: 1, Percentage: 0.01%
# Wisconsin Dells: Count: 1, Percentage: 0.01%
# Wisconsin Rapids: Count: 1, Percentage: 0.01%
# Wise: Count: 1, Percentage: 0.01%
# Wishek: Count: 1, Percentage: 0.01%
# Witt: Count: 1, Percentage: 0.01%
# Wixom: Count: 1, Percentage: 0.01%
# Woburn: Count: 1, Percentage: 0.01%
# Wolcott: Count: 1, Percentage: 0.01%
# Wolf Point: Count: 1, Percentage: 0.01%
# Wolfeboro: Count: 1, Percentage: 0.01%
# Wolfforth7: Count: 1, Percentage: 0.01%
# Wolverine Lake: Count: 1, Percentage: 0.01%
# Womelsdorf: Count: 1, Percentage: 0.01%
# Wonder Lake: Count: 1, Percentage: 0.01%
# Wood Dale: Count: 1, Percentage: 0.01%
# Wood Heights: Count: 1, Percentage: 0.01%
# Wood River: Count: 1, Percentage: 0.01%
# Wood-Ridge: Count: 1, Percentage: 0.01%
# Woodbranch: Count: 1, Percentage: 0.01%
# Woodbridge: Count: 1, Percentage: 0.01%
# Woodbridge Township: Count: 1, Percentage: 0.01%
# Woodburn: Count: 2, Percentage: 0.02%
# Woodbury: Count: 4, Percentage: 0.04%
# Woodbury Heights: Count: 1, Percentage: 0.01%
# Woodbury Town: Count: 1, Percentage: 0.01%
# Woodcliff Lake: Count: 1, Percentage: 0.01%
# Woodfin: Count: 1, Percentage: 0.01%
# Woodhaven: Count: 1, Percentage: 0.01%
# Woodinville: Count: 1, Percentage: 0.01%
# Woodlake: Count: 1, Percentage: 0.01%
# Woodland: Count: 3, Percentage: 0.03%
# Woodland Park: Count: 2, Percentage: 0.02%
# Woodland Township: Count: 1, Percentage: 0.01%
# Woodlawn: Count: 1, Percentage: 0.01%
# Woodlynne: Count: 1, Percentage: 0.01%
# Woodmere Village: Count: 1, Percentage: 0.01%
# Woodridge: Count: 1, Percentage: 0.01%
# Woodridge Village: Count: 1, Percentage: 0.01%
# Woodruff: Count: 2, Percentage: 0.02%
# Woods Cross: Count: 1, Percentage: 0.01%
# Woodson Terrace: Count: 1, Percentage: 0.01%
# Woodstock: Count: 5, Percentage: 0.05%
# Woodstock Town: Count: 1, Percentage: 0.01%
# Woodstown: Count: 1, Percentage: 0.01%
# Woodville: Count: 1, Percentage: 0.01%
# Woodward: Count: 1, Percentage: 0.01%
# Woodway: Count: 2, Percentage: 0.02%
# Woolwich Township: Count: 1, Percentage: 0.01%
# Woonsocket: Count: 1, Percentage: 0.01%
# Wooster: Count: 1, Percentage: 0.01%
# Worcester: Count: 1, Percentage: 0.01%
# Worland: Count: 1, Percentage: 0.01%
# Worth: Count: 1, Percentage: 0.01%
# Wortham: Count: 1, Percentage: 0.01%
# Worthing: Count: 1, Percentage: 0.01%
# Worthington: Count: 4, Percentage: 0.04%
# Wrangell: Count: 1, Percentage: 0.01%
# Wray: Count: 1, Percentage: 0.01%
# Wrens: Count: 1, Percentage: 0.01%
# Wrentham: Count: 1, Percentage: 0.01%
# Wright City: Count: 2, Percentage: 0.02%
# Wright Township: Count: 1, Percentage: 0.01%
# Wrightsville Beach: Count: 1, Percentage: 0.01%
# Wyandotte: Count: 2, Percentage: 0.02%
# Wyckoff Township: Count: 1, Percentage: 0.01%
# Wylie: Count: 1, Percentage: 0.01%
# Wynne: Count: 1, Percentage: 0.01%
# Wynnewood: Count: 1, Percentage: 0.01%
# Wyoming: Count: 5, Percentage: 0.05%
# Wyomissing: Count: 1, Percentage: 0.01%
# Wytheville: Count: 1, Percentage: 0.01%
# Xenia: Count: 1, Percentage: 0.01%
# Yadkinville: Count: 1, Percentage: 0.01%
# Yakima: Count: 1, Percentage: 0.01%
# Yale: Count: 2, Percentage: 0.02%
# Yamhill: Count: 1, Percentage: 0.01%
# Yankton: Count: 1, Percentage: 0.01%
# Yardley: Count: 1, Percentage: 0.01%
# Yarmouth10: Count: 1, Percentage: 0.01%
# Yarmouth4: Count: 1, Percentage: 0.01%
# Yarrow Point: Count: 1, Percentage: 0.01%
# Yates Center: Count: 1, Percentage: 0.01%
# Yates City: Count: 1, Percentage: 0.01%
# Yeadon: Count: 1, Percentage: 0.01%
# Yellow Springs7: Count: 1, Percentage: 0.01%
# Yelm: Count: 1, Percentage: 0.01%
# Yerington: Count: 1, Percentage: 0.01%
# Yoakum: Count: 1, Percentage: 0.01%
# Yonkers: Count: 1, Percentage: 0.01%
# Yorba Linda: Count: 1, Percentage: 0.01%
# York: Count: 4, Percentage: 0.04%
# York Area Regional: Count: 1, Percentage: 0.01%
# Yorktown: Count: 1, Percentage: 0.01%
# Yorktown Town: Count: 1, Percentage: 0.01%
# Yorkville: Count: 1, Percentage: 0.01%
# Yorkville Village: Count: 1, Percentage: 0.01%
# Youngstown: Count: 1, Percentage: 0.01%
# Youngstown Village: Count: 1, Percentage: 0.01%
# Youngsville: Count: 2, Percentage: 0.02%
# Yountville: Count: 1, Percentage: 0.01%
# Ypsilanti: Count: 1, Percentage: 0.01%
# Yreka: Count: 1, Percentage: 0.01%
# Yuba City: Count: 1, Percentage: 0.01%
# Yucaipa: Count: 1, Percentage: 0.01%
# Yucca Valley: Count: 1, Percentage: 0.01%
# Yukon: Count: 1, Percentage: 0.01%
# Yuma: Count: 1, Percentage: 0.01%
# Zachary: Count: 1, Percentage: 0.01%
# Zanesville: Count: 1, Percentage: 0.01%
# Zebulon: Count: 1, Percentage: 0.01%
# Zeeland: Count: 1, Percentage: 0.01%
# Zeigler: Count: 1, Percentage: 0.01%
# Zephyrhills: Count: 1, Percentage: 0.01%
# Zillah: Count: 1, Percentage: 0.01%
# Zilwaukee: Count: 1, Percentage: 0.01%
# Zion: Count: 1, Percentage: 0.01%
# Zionsville: Count: 1, Percentage: 0.01%
# Zumbrota: Count: 1, Percentage: 0.01%
# percentage_of_nan_systemic :  0.0 %
# ##########################################################################################

# %%
df_copy = df.copy()
df_copy["violent crimes"] = df_copy["Murder"] + df_copy["Rape"] + df_copy["Robbery"] + df_copy["Assault"]
df_copy["non-violent crimes"] = df_copy["Burglary"] + df_copy["Theft"] + df_copy["Vehicle_Theft"]
df_copy = df_copy.drop(["Murder","Rape","Robbery","Assault","Burglary","Theft","Vehicle_Theft"], axis =1)
df_copy.head()
# Out:
#   Region    State         City Population  violent crimes  non-violent crimes
# 0  South  ALABAMA    Abbeville       2608              11                  51
# 1  South  ALABAMA   Adamsville       4377              19                 250
# 2  South  ALABAMA      Addison        738               1                  14
# 3  South  ALABAMA    Alabaster      33040              97                 488
# 4  South  ALABAMA  Albertville      21525              29                 721

# %%
df_new = df.copy()
df_new["violent crimes"] = df_new[df_new.columns[4:8]].sum(axis=1) 
df_new["non-violent crimes"]  = df_new[df_new.columns[8:]].sum(axis=1)
df_new = df_new.drop(["Murder","Rape","Robbery","Assault","Burglary","Theft","Vehicle_Theft"], axis =1)
df_new.head()
# Out:
#   Region    State         City Population  violent crimes  non-violent crimes
# 0  South  ALABAMA    Abbeville       2608              11                  62
# 1  South  ALABAMA   Adamsville       4377              19                 269
# 2  South  ALABAMA      Addison        738               1                  15
# 3  South  ALABAMA    Alabaster      33040              97                 585
# 4  South  ALABAMA  Albertville      21525              29                 750

# %%
df_copy.groupby("Region").agg("count")
# Out:
#            State  City  Population  violent crimes  non-violent crimes
# Region
# Midwest     2829  2829        2829            2829                2829
# Northeast   2403  2403        2403            2403                2403
# South       3038  3038        3038            3038                3038
# West        1309  1309        1309            1309                1309

# %%
df.groupby("Region").agg("sum")["Murder"]
# Out:
# Region
# Midwest      3304
# Northeast    1674
# South        5018
# West         2605
# Name: Murder, dtype: int64

# %%
# df_copy.plot.bar(x=None, y=None, **kwargs)

# %% [markdown]
# # 1

# %%
###############################################################################################################

# %%
murder_by_region = dict()
violent_by_region = dict()
nonviolent_by_region = dict()
 
region_list = ["South","West","Northeast","Midwest"]
crime_list = ['Murder','Rape','Robbery','Assault','Burglary','Theft','Vehicle_Theft']

for rgn in region_list :
    for crm  in crime_list[0:4] :
        
        for  numb in df[df["Region"]==rgn].loc[:,crm] :
            if rgn not in violent_by_region  :
                violent_by_region[rgn] = numb
            else :
                violent_by_region[rgn] += numb
        
        if crm == "Murder" :
            for numb in df[df["Region"]==rgn].loc[:,crm] :
                if rgn not in murder_by_region  :
                    murder_by_region[rgn] = numb 
                else :
                    murder_by_region[rgn] += numb 
            
    for crm  in crime_list[4:] :
        
        for numb in df[df["Region"]==rgn].loc[:,crm] :
            if rgn not in nonviolent_by_region  :
                nonviolent_by_region[rgn] = numb
            else :
                nonviolent_by_region[rgn] += numb
                
print(murder_by_region) 
print( pd.DataFrame({"Incident":murder_by_region.values() , "Region":murder_by_region.keys() }) )
print("#"*90)
print(violent_by_region) 
print( pd.DataFrame({"Incident":violent_by_region.values() , "Region":violent_by_region.keys() }) )
print("#"*90)
print(nonviolent_by_region) 
print( pd.DataFrame({"Incident":nonviolent_by_region.values() , "Region":nonviolent_by_region.keys() }) )
print("#"*90)


crimes=list()
new = list()
number_states = df["State"].unique().shape[0] ### 51
df["violent_crimes"] = df["Murder"] + df["Rape"] + df["Robbery"] + df["Assault"] 
mean_violent_crimes = df["violent_crimes"].sum() / number_states
for state in df["State"].unique() : 
    crimes.append( df[ df["State"]==state ]["violent_crimes"].sum() )

talubar_report = pd.DataFrame( { "STATE":df["State"].unique() ,"CRIMES":crimes , "DISTANCE FROM MEAN" :crimes - mean_violent_crimes } )
talubar_report
# Out:
# {'South': 5018, 'West': 2605, 'Northeast': 1674, 'Midwest': 3304}
#    Incident     Region
# 0      5018      South
# 1      2605       West
# 2      1674  Northeast
# 3      3304    Midwest
# ##########################################################################################
# {'South': 331011, 'West': 259401, 'Northeast': 156891, 'Midwest': 211854}
#    Incident     Region
# 0    331011      South
# 1    259401       West
# 2    156891  Northeast
# 3    211854    Midwest
# ##########################################################################################
# {'South': 2080097, 'West': 1781665, 'Northeast': 760200, 'Midwest': 1226462}
#    Incident     Region
# 0   2080097      South
# 1   1781665       West
# 2    760200  Northeast
# 3   1226462    Midwest
# ##########################################################################################
#                    STATE  CRIMES  DISTANCE FROM MEAN
# 0                ALABAMA   15350             -3457.0
# 1                 ALASKA    4697            -14110.0
# 2                ARIZONA   23856              5049.0
# 3               ARKANSAS   12048             -6759.0
# 4             CALIFORNIA  145205            126398.0
# 5               COLORADO   15533             -3274.0
# 6            CONNECTICUT    7754            -11053.0
# 7               DELAWARE    2359            -16448.0
# 8   DISTRICT OF COLUMBIA    7711            -11096.0
# 9                FLORIDA   50540             31733.0
# 10               GEORGIA   18496              -311.0
# 11                HAWAII    3331            -15476.0
# 12                 IDAHO    2676            -16131.0
# 13              ILLINOIS   50968             32161.0
# 14               INDIANA   21325              2518.0
# 15                  IOWA    7533            -11274.0
# 16                KANSAS    7982            -10825.0
# 17              KENTUCKY    8342            -10465.0
# 18             LOUISIANA   16444             -2363.0
# 19                 MAINE    1254            -17553.0
# 20              MARYLAND   14175             -4632.0
# 21         MASSACHUSETTS   24155              5348.0
# 22              MICHIGAN   35790             16983.0
# 23             MINNESOTA   11618             -7189.0
# 24           MISSISSIPPI    3256            -15551.0
# 25              MISSOURI   25175              6368.0
# 26               MONTANA    1952            -16855.0
# 27              NEBRASKA    4401            -14406.0
# 28                NEVADA   18823                16.0
# 29         NEW HAMPSHIRE    2413            -16394.0
# 30            NEW JERSEY   19098               291.0
# 31            NEW MEXICO    9480             -9327.0
# 32              NEW YORK   66581             47774.0
# 33        NORTH CAROLINA   16846             -1961.0
# 34          NORTH DAKOTA    1393            -17414.0
# 35                  OHIO   28235              9428.0
# 36              OKLAHOMA   15348             -3459.0
# 37                OREGON    7785            -11022.0
# 38          PENNSYLVANIA   32877             14070.0
# 39          RHODE ISLAND    2423            -16384.0
# 40        SOUTH CAROLINA    9473             -9334.0
# 41          SOUTH DAKOTA    2169            -16638.0
# 42             TENNESSEE   33433             14626.0
# 43                 TEXAS   97872             79065.0
# 44                  UTAH    5679            -13128.0
# 45               VERMONT     336            -18471.0
# 46              VIRGINIA    9318             -9489.0
# 47            WASHINGTON   16913             -1894.0
# 48         WEST VIRGINIA    2701            -16106.0
# 49             WISCONSIN   15265             -3542.0
# 50               WYOMING     770            -18037.0

# %% [markdown]
# # 2

# %%
###############################################################################################################

# %%
murder_by_region = dict()
violent_by_region = dict()
nonviolent_by_region = dict()
 
region_list = ["South","West","Northeast","Midwest"]
# crime_list = ['Murder','Rape','Robbery','Assault','Burglary','Theft','Vehicle_Theft']
rgn_ctrl = 0
crm_ctrl = 4
flag_1 = 0

while True :
    if rgn_ctrl <= 3 and flag_1 == 0 :
        if  crm_ctrl == 4 :
            murder_by_region[region_list[rgn_ctrl]] = murder_by_region.get(region_list[rgn_ctrl],0) + df[df["Region"]==region_list[rgn_ctrl]].iloc[:,crm_ctrl].sum()
                 
        if crm_ctrl <= 7 :
            violent_by_region[region_list[rgn_ctrl]] = violent_by_region.get(region_list[rgn_ctrl],0) + df[ df["Region"]==region_list[rgn_ctrl] ].iloc[:,crm_ctrl].sum()
       
        if crm_ctrl > 7 and crm_ctrl < 11 :   
            nonviolent_by_region[region_list[rgn_ctrl]] = nonviolent_by_region.get(region_list[rgn_ctrl],0) + df[df["Region"]==region_list[rgn_ctrl]].iloc[:,crm_ctrl].sum()

        if  crm_ctrl >= 11:
            flag_1 = 1
            
    crm_ctrl += 1
    
    if rgn_ctrl > 3 :
        break
        
    if flag_1 == 1 :
        crm_ctrl = 4
        flag_1 = 0
        rgn_ctrl += 1
        

                
print(murder_by_region) 
df_murder_by_region = pd.DataFrame({"Incident":murder_by_region.values() , "Region":murder_by_region.keys() })
print( pd.DataFrame({"Incident":murder_by_region.values() , "Region":murder_by_region.keys() }) )
df_murder_by_region.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

print("#"*90)

df_violent_by_region = pd.DataFrame({"Incident":violent_by_region.values() , "Region":violent_by_region.keys() })
print(violent_by_region) 
print( pd.DataFrame({"Incident":violent_by_region.values() , "Region":violent_by_region.keys() }) )
df_violent_by_region.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

print("#"*90)

df_nonviolent_by_region = pd.DataFrame({"Incident":nonviolent_by_region.values() , "Region":nonviolent_by_region.keys() })
print(nonviolent_by_region) 
print( pd.DataFrame({"Incident":nonviolent_by_region.values() , "Region":nonviolent_by_region.keys()}) )
df_nonviolent_by_region.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

print("#"*90)
# Out:
# {'South': 5018, 'West': 2605, 'Northeast': 1674, 'Midwest': 3304}
#    Incident     Region
# 0      5018      South
# 1      2605       West
# 2      1674  Northeast
# 3      3304    Midwest
# ##########################################################################################
# {'South': 331011, 'West': 259401, 'Northeast': 156891, 'Midwest': 211854}
#    Incident     Region
# 0    331011      South
# 1    259401       West
# 2    156891  Northeast
# 3    211854    Midwest
# ##########################################################################################
# {'South': 2080097, 'West': 1781665, 'Northeast': 760200, 'Midwest': 1226462}
#    Incident     Region
# 0   2080097      South
# 1   1781665       West
# 2    760200  Northeast
# 3   1226462    Midwest
# ##########################################################################################

# %%
crimes=list()
new = list()
number_states = df["State"].unique().shape[0] ### 51
df["violent_crimes"] = df["Murder"] + df["Rape"] + df["Robbery"] + df["Assault"] 
mean_violent_crimes = df["violent_crimes"].sum() / number_states
for state in df["State"].unique() : 
    crimes.append( df[ df["State"]==state ]["violent_crimes"].sum() )
#     new.append( minus )
talubar_report = pd.DataFrame( { "STATE":df["State"].unique() ,"CRIMES":crimes , "DISTANCE FROM MEAN" :crimes - mean_violent_crimes } )
print(talubar_report)
# Out:
#                    STATE  CRIMES  DISTANCE FROM MEAN
# 0                ALABAMA   15350             -3457.0
# 1                 ALASKA    4697            -14110.0
# 2                ARIZONA   23856              5049.0
# 3               ARKANSAS   12048             -6759.0
# 4             CALIFORNIA  145205            126398.0
# 5               COLORADO   15533             -3274.0
# 6            CONNECTICUT    7754            -11053.0
# 7               DELAWARE    2359            -16448.0
# 8   DISTRICT OF COLUMBIA    7711            -11096.0
# 9                FLORIDA   50540             31733.0
# 10               GEORGIA   18496              -311.0
# 11                HAWAII    3331            -15476.0
# 12                 IDAHO    2676            -16131.0
# 13              ILLINOIS   50968             32161.0
# 14               INDIANA   21325              2518.0
# 15                  IOWA    7533            -11274.0
# 16                KANSAS    7982            -10825.0
# 17              KENTUCKY    8342            -10465.0
# 18             LOUISIANA   16444             -2363.0
# 19                 MAINE    1254            -17553.0
# 20              MARYLAND   14175             -4632.0
# 21         MASSACHUSETTS   24155              5348.0
# 22              MICHIGAN   35790             16983.0
# 23             MINNESOTA   11618             -7189.0
# 24           MISSISSIPPI    3256            -15551.0
# 25              MISSOURI   25175              6368.0
# 26               MONTANA    1952            -16855.0
# 27              NEBRASKA    4401            -14406.0
# 28                NEVADA   18823                16.0
# 29         NEW HAMPSHIRE    2413            -16394.0
# 30            NEW JERSEY   19098               291.0
# 31            NEW MEXICO    9480             -9327.0
# 32              NEW YORK   66581             47774.0
# 33        NORTH CAROLINA   16846             -1961.0
# 34          NORTH DAKOTA    1393            -17414.0
# 35                  OHIO   28235              9428.0
# 36              OKLAHOMA   15348             -3459.0
# 37                OREGON    7785            -11022.0
# 38          PENNSYLVANIA   32877             14070.0
# 39          RHODE ISLAND    2423            -16384.0
# 40        SOUTH CAROLINA    9473             -9334.0
# 41          SOUTH DAKOTA    2169            -16638.0
# 42             TENNESSEE   33433             14626.0
# 43                 TEXAS   97872             79065.0
# 44                  UTAH    5679            -13128.0
# 45               VERMONT     336            -18471.0
# 46              VIRGINIA    9318             -9489.0
# 47            WASHINGTON   16913             -1894.0
# 48         WEST VIRGINIA    2701            -16106.0
# 49             WISCONSIN   15265             -3542.0
# 50               WYOMING     770            -18037.0

# %% [markdown]
# # 3

# %%
###############################################################################################################

# %%
def crime_report ( crime , DF ) :
    ind = 0
    CrRprt = dict()
    Region =   DF["Region"]  
    numb =   DF[crime]  
    for rgn  in Region :
        if rgn not in CrRprt :
            CrRprt[rgn] = 0
#         if rgn in crm_report : 
        CrRprt[rgn] += numb[ind] 
        ind += 1
    return CrRprt

print( crime_report("Murder",df) )

print("#"*90)#######################################################################################################

df_murder_by_region = pd.DataFrame({"Incident":crime_report("Murder",df).values() ,"Region":crime_report("Murder",df).keys() })
print( "\n",df_murder_by_region,"\n" )

print("#"*90)#######################################################################################################

def PLOT ( IN_dictionary ) :
    df_specified = pd.DataFrame({"Incident":IN_dictionary.values() , "Region":IN_dictionary.keys() })    
    return df_specified.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

PLOT( crime_report( "Murder" , df) ) 

print("#"*90)#######################################################################################################
# Out:
# {'South': 5018, 'West': 2605, 'Northeast': 1674, 'Midwest': 3304}
# ##########################################################################################
#
#     Incident     Region
# 0      5018      South
# 1      2605       West
# 2      1674  Northeast
# 3      3304    Midwest
#
# ##########################################################################################
# ##########################################################################################

# %%
def violent_report ( DF ) :
    ind = 0
    ViRprt = dict()
    Region = DF["Region"] 
    numb = DF["Murder"] + DF["Rape"] + DF["Robbery"] + DF["Assault"]   
    for rgn  in Region :
        if rgn not in ViRprt :
            ViRprt[rgn] = 0
#         if rgn in crm_report : 
        ViRprt[rgn] += numb[ind] 
        ind += 1
    return ViRprt

print( violent_report(df) )

print("#"*90)#######################################################################################################

df_violent_by_region = pd.DataFrame({"Incident":violent_report (df).values() , "Region":violent_report (df).keys() })
print( "\n",df_violent_by_region,"\n" )

print("#"*90)#######################################################################################################

def PLOT ( IN_dictionary ) :
    df_specified = pd.DataFrame({"Incident":IN_dictionary.values() , "Region":IN_dictionary.keys() })    
    return df_specified.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

PLOT( violent_report(df) ) 

print("#"*90)#######################################################################################################
# Out:
# {'South': 331011, 'West': 259401, 'Northeast': 156891, 'Midwest': 211854}
# ##########################################################################################
#
#     Incident     Region
# 0    331011      South
# 1    259401       West
# 2    156891  Northeast
# 3    211854    Midwest
#
# ##########################################################################################
# ##########################################################################################

# %%
def non_violent_report ( DF ) :
    ind = 0
    nonViRprt = dict()
    Region = DF["Region"] 
    numb = DF['Burglary'] + DF['Theft'] + DF['Vehicle_Theft']   
    for rgn  in Region :
        if rgn not in nonViRprt :
            nonViRprt[rgn] = 0
#         if rgn in crm_report : 
        nonViRprt[rgn] += numb[ind] 
        ind += 1
    return nonViRprt

print( non_violent_report(df) ) 

print("#"*90)#######################################################################################################

df_non_violent_by_region = pd.DataFrame( {"Incident":non_violent_report(df).values(),"Region":non_violent_report(df).keys()} )
print( "\n", df_non_violent_by_region ,"\n" )

print("#"*90)#######################################################################################################

def PLOT ( IN_dictionary ) :
    df_specified = pd.DataFrame( {"Incident":IN_dictionary.values() , "Region":IN_dictionary.keys()} )    
    return df_specified.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

PLOT( non_violent_report(df) ) 

print("#"*90)#######################################################################################################
# Out:
# {'South': 2080097, 'West': 1781665, 'Northeast': 760200, 'Midwest': 1226462}
# ##########################################################################################
#
#     Incident     Region
# 0   2080097      South
# 1   1781665       West
# 2    760200  Northeast
# 3   1226462    Midwest
#
# ##########################################################################################
# ##########################################################################################

# %%
def distance_state_from_mean ( DF ) :
    list_violent_crimes = DF["Murder"] + DF["Rape"] + DF["Robbery"] + DF["Assault"]
    list_state = DF["State"]
    total = 0
    state_numb_dict = dict()
    list_difference = list()
    for numb , state in zip(list_violent_crimes,list_state) :
        total += numb
        if state not in state_numb_dict :
            state_numb_dict[state] = 0
        state_numb_dict[state] += numb
    mean_dict = total / len (state_numb_dict.keys())
    for i in state_numb_dict.values() :
        list_difference . append(i - mean_dict) 
    talubar_report = pd.DataFrame({"STATE":state_numb_dict.keys(),"CRIMES":state_numb_dict.values() ,"DISTANCE FROM MEAN":list_difference } )  
    return talubar_report

print( distance_state_from_mean(df) )


####################################################################################################################################################
# Out:
#                    STATE  CRIMES  DISTANCE FROM MEAN
# 0                ALABAMA   15350             -3457.0
# 1                 ALASKA    4697            -14110.0
# 2                ARIZONA   23856              5049.0
# 3               ARKANSAS   12048             -6759.0
# 4             CALIFORNIA  145205            126398.0
# 5               COLORADO   15533             -3274.0
# 6            CONNECTICUT    7754            -11053.0
# 7               DELAWARE    2359            -16448.0
# 8   DISTRICT OF COLUMBIA    7711            -11096.0
# 9                FLORIDA   50540             31733.0
# 10               GEORGIA   18496              -311.0
# 11                HAWAII    3331            -15476.0
# 12                 IDAHO    2676            -16131.0
# 13              ILLINOIS   50968             32161.0
# 14               INDIANA   21325              2518.0
# 15                  IOWA    7533            -11274.0
# 16                KANSAS    7982            -10825.0
# 17              KENTUCKY    8342            -10465.0
# 18             LOUISIANA   16444             -2363.0
# 19                 MAINE    1254            -17553.0
# 20              MARYLAND   14175             -4632.0
# 21         MASSACHUSETTS   24155              5348.0
# 22              MICHIGAN   35790             16983.0
# 23             MINNESOTA   11618             -7189.0
# 24           MISSISSIPPI    3256            -15551.0
# 25              MISSOURI   25175              6368.0
# 26               MONTANA    1952            -16855.0
# 27              NEBRASKA    4401            -14406.0
# 28                NEVADA   18823                16.0
# 29         NEW HAMPSHIRE    2413            -16394.0
# 30            NEW JERSEY   19098               291.0
# 31            NEW MEXICO    9480             -9327.0
# 32              NEW YORK   66581             47774.0
# 33        NORTH CAROLINA   16846             -1961.0
# 34          NORTH DAKOTA    1393            -17414.0
# 35                  OHIO   28235              9428.0
# 36              OKLAHOMA   15348             -3459.0
# 37                OREGON    7785            -11022.0
# 38          PENNSYLVANIA   32877             14070.0
# 39          RHODE ISLAND    2423            -16384.0
# 40        SOUTH CAROLINA    9473             -9334.0
# 41          SOUTH DAKOTA    2169            -16638.0
# 42             TENNESSEE   33433             14626.0
# 43                 TEXAS   97872             79065.0
# 44                  UTAH    5679            -13128.0
# 45               VERMONT     336            -18471.0
# 46              VIRGINIA    9318             -9489.0
# 47            WASHINGTON   16913             -1894.0
# 48         WEST VIRGINIA    2701            -16106.0
# 49             WISCONSIN   15265             -3542.0
# 50               WYOMING     770            -18037.0

# %%
def distance_state_from_mean () :
    list_violent_crimes = df["Murder"] + df["Rape"] + df["Robbery"] + df["Assault"]
    list_state = df["State"]
    total = 0
    state_numb_dict = dict()
    for  state,numb in zip(list_state,list_violent_crimes) :
        total += numb
        if state not in state_numb_dict :
            state_numb_dict[state] = 0
        state_numb_dict[state] += numb
    mean_dict = total / len(state_numb_dict)
    minus_column = ( pd.DataFrame(state_numb_dict.values())-mean_dict ) [0]
#     talubar_report = pd.DataFrame({"STATE":list(state_numb_dict.keys()),"CRIMES":list(state_numb_dict.values()) }) #,"DISTANCE_FROM_MEAN":state_numb_dict.values()-mean_dict} ) 
#     talubar_report["DISTANCE_FROM_MEAN"] = minus_colum                              
#     return talubar_report
    return state_numb_dict


print( distance_state_from_mean() )
# Out:
# {'ALABAMA': 15350, 'ALASKA': 4697, 'ARIZONA': 23856, 'ARKANSAS': 12048, 'CALIFORNIA': 145205, 'COLORADO': 15533, 'CONNECTICUT': 7754, 'DELAWARE': 2359, 'DISTRICT OF COLUMBIA': 7711, 'FLORIDA': 50540, 'GEORGIA': 18496, 'HAWAII': 3331, 'IDAHO': 2676, 'ILLINOIS': 50968, 'INDIANA': 21325, 'IOWA': 7533, 'KANSAS': 7982, 'KENTUCKY': 8342, 'LOUISIANA': 16444, 'MAINE': 1254, 'MARYLAND': 14175, 'MASSACHUSETTS': 24155, 'MICHIGAN': 35790, 'MINNESOTA': 11618, 'MISSISSIPPI': 3256, 'MISSOURI': 25175, 'MONTANA': 1952, 'NEBRASKA': 4401, 'NEVADA': 18823, 'NEW HAMPSHIRE': 2413, 'NEW JERSEY': 19098, 'NEW MEXICO': 9480, 'NEW YORK': 66581, 'NORTH CAROLINA': 16846, 'NORTH DAKOTA': 1393, 'OHIO': 28235, 'OKLAHOMA': 15348, 'OREGON': 7785, 'PENNSYLVANIA': 32877, 'RHODE ISLAND': 2423, 'SOUTH CAROLINA': 9473, 'SOUTH DAKOTA': 2169, 'TENNESSEE': 33433, 'TEXAS': 97872, 'UTAH': 5679, 'VERMONT': 336, 'VIRGINIA': 9318, 'WASHINGTON': 16913, 'WEST VIRGINIA': 2701, 'WISCONSIN': 15265, 'WYOMING': 770}

# %% [markdown]
# # 4

# %%
def crime_report ( crime , DF ) :
    ind = 0
    CrRprt = dict()
    Region =   DF["Region"]  
    numb =   DF[crime]  
    for rgn  in Region :
        if rgn not in CrRprt :
            CrRprt[rgn] = 0
#         if rgn in crm_report : 
        CrRprt[rgn] += numb[ind] 
        ind += 1
    return CrRprt

print( crime_report("Murder",df) )

print("#"*90)#######################################################################################################

print("                  incidents                      Region    \n")
for i , j , k in zip( range(0,len(crime_report("Murder",df))) , crime_report("Murder",df).values() , crime_report("Murder",df).keys() ) :
    print( "{0}                   {1}                         {2}".format(i,j,k) )

print("#"*90)#######################################################################################################

def PLOT ( IN_dictionary ) :
    df_specified = pd.DataFrame({"Incident":IN_dictionary.values() , "Region":IN_dictionary.keys() })    
    return df_specified.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

PLOT( crime_report( "Murder" , df) ) 

print("#"*90)#######################################################################################################
# Out:
# {'South': 5018, 'West': 2605, 'Northeast': 1674, 'Midwest': 3304}
# ##########################################################################################
#                   incidents                      Region
#
# 0                   5018                         South
# 1                   2605                         West
# 2                   1674                         Northeast
# 3                   3304                         Midwest
# ##########################################################################################
# ##########################################################################################

# %%
def violent_report ( DF ) :
    ind = 0
    ViRprt = dict()
    Region = DF["Region"] 
    numb = DF["Murder"] + DF["Rape"] + DF["Robbery"] + DF["Assault"]   
    for rgn  in Region :
        if rgn not in ViRprt :
            ViRprt[rgn] = 0
#         if rgn in crm_report : 
        ViRprt[rgn] += numb[ind] 
        ind += 1
    return ViRprt

print( violent_report(df) )

print("#"*90)#######################################################################################################

print("                  incidents                       Region    \n")
for i , j , k in zip( range(0,len(violent_report(df))) , violent_report(df).values() , violent_report(df).keys() ) :
    print( "{0}                   {1}                         {2}".format(i,j,k) )

print("#"*90)#######################################################################################################

def PLOT ( IN_dictionary ) :
    df_specified = pd.DataFrame({"Incident":IN_dictionary.values() , "Region":IN_dictionary.keys() })    
    return df_specified.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

PLOT( violent_report(df) ) 

print("#"*90)#######################################################################################################
# Out:
# {'South': 331011, 'West': 259401, 'Northeast': 156891, 'Midwest': 211854}
# ##########################################################################################
#                   incidents                       Region
#
# 0                   331011                         South
# 1                   259401                         West
# 2                   156891                         Northeast
# 3                   211854                         Midwest
# ##########################################################################################
# ##########################################################################################

# %%
def non_violent_report ( DF ) :
    ind = 0
    nonViRprt = dict()
    Region = DF["Region"] 
    numb = DF['Burglary'] + DF['Theft'] + DF['Vehicle_Theft']   
    for rgn  in Region :
        if rgn not in nonViRprt :
            nonViRprt[rgn] = 0
#         if rgn in crm_report : 
        nonViRprt[rgn] += numb[ind] 
        ind += 1
    return nonViRprt

print( non_violent_report(df) ) 

print("#"*90)#######################################################################################################

print("                   incidents                        Region    \n")
for i , j , k in zip( range(0,len(non_violent_report(df)))  , non_violent_report(df).values() , non_violent_report(df).keys() ) :
    print( "{0}                   {1}                         {2}".format(i,j,k) )


print("#"*90)#######################################################################################################

def PLOT ( IN_dictionary ) :
    df_specified = pd.DataFrame( {"Incident":IN_dictionary.values() , "Region":IN_dictionary.keys()} )    
    return df_specified.plot( x="Region",y="Incident",kind="bar",color = ['blue','yellow','purple','red'] )

PLOT( non_violent_report(df) ) 

print("#"*90)#######################################################################################################
# Out:
# {'South': 2080097, 'West': 1781665, 'Northeast': 760200, 'Midwest': 1226462}
# ##########################################################################################
#                    incidents                        Region
#
# 0                   2080097                         South
# 1                   1781665                         West
# 2                   760200                         Northeast
# 3                   1226462                         Midwest
# ##########################################################################################
# ##########################################################################################

# %%
def violent_distance_state_from_mean () :
    list_violent_crimes = df["Murder"] + df["Rape"] + df["Robbery"] + df["Assault"]
    list_state = df["State"]
    total = 0
    state_numb_dict = dict()
    for  state,numb in zip(list_state,list_violent_crimes) :
        total += numb
        if state not in state_numb_dict :
            state_numb_dict[state] = 0
        state_numb_dict[state] += numb
    mean_dict = total / len(state_numb_dict)
    print( "STATE                                  CRIMES                    DISTANCE FROM MEAN \n")
    for i , j  in  zip( state_numb_dict.keys() ,  state_numb_dict.values() ) :
        print( "{0:<20}                   {1}                         {2}".format(i,j,j-mean_dict) )
    


violent_distance_state_from_mean()
# Out:
# STATE                                  CRIMES                    DISTANCE FROM MEAN
#
# ALABAMA                                15350                         -3457.0
# ALASKA                                 4697                         -14110.0
# ARIZONA                                23856                         5049.0
# ARKANSAS                               12048                         -6759.0
# CALIFORNIA                             145205                         126398.0
# COLORADO                               15533                         -3274.0
# CONNECTICUT                            7754                         -11053.0
# DELAWARE                               2359                         -16448.0
# DISTRICT OF COLUMBIA                   7711                         -11096.0
# FLORIDA                                50540                         31733.0
# GEORGIA                                18496                         -311.0
# HAWAII                                 3331                         -15476.0
# IDAHO                                  2676                         -16131.0
# ILLINOIS                               50968                         32161.0
# INDIANA                                21325                         2518.0
# IOWA                                   7533                         -11274.0
# KANSAS                                 7982                         -10825.0
# KENTUCKY                               8342                         -10465.0
# LOUISIANA                              16444                         -2363.0
# MAINE                                  1254                         -17553.0
# MARYLAND                               14175                         -4632.0
# MASSACHUSETTS                          24155                         5348.0
# MICHIGAN                               35790                         16983.0
# MINNESOTA                              11618                         -7189.0
# MISSISSIPPI                            3256                         -15551.0
# MISSOURI                               25175                         6368.0
# MONTANA                                1952                         -16855.0
# NEBRASKA                               4401                         -14406.0
# NEVADA                                 18823                         16.0
# NEW HAMPSHIRE                          2413                         -16394.0
# NEW JERSEY                             19098                         291.0
# NEW MEXICO                             9480                         -9327.0
# NEW YORK                               66581                         47774.0
# NORTH CAROLINA                         16846                         -1961.0
# NORTH DAKOTA                           1393                         -17414.0
# OHIO                                   28235                         9428.0
# OKLAHOMA                               15348                         -3459.0
# OREGON                                 7785                         -11022.0
# PENNSYLVANIA                           32877                         14070.0
# RHODE ISLAND                           2423                         -16384.0
# SOUTH CAROLINA                         9473                         -9334.0
# SOUTH DAKOTA                           2169                         -16638.0
# TENNESSEE                              33433                         14626.0
# TEXAS                                  97872                         79065.0
# UTAH                                   5679                         -13128.0
# VERMONT                                336                         -18471.0
# VIRGINIA                               9318                         -9489.0
# WASHINGTON                             16913                         -1894.0
# WEST VIRGINIA                          2701                         -16106.0
# WISCONSIN                              15265                         -3542.0
# WYOMING                                770                         -18037.0
